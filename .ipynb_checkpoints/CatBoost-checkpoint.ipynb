# %% [markdown]
# # CatBoostClassifier

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 2000) # since we have a lot of features
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import RepeatedStratifiedKFold

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("data"))
# Out:
# ['test.csv', 'train.csv', 'sample_submission.csv']

# %%
''' Import data '''

DATA_DIR = 'data'
train_file = os.path.join(DATA_DIR, 'train.csv')
test_file = os.path.join(DATA_DIR, 'test.csv')
submission_file = os.path.join(DATA_DIR, 'sample_submission.csv')

train = pd.read_csv(train_file)
test = pd.read_csv(test_file)

X = train.drop(columns=['y', 'sample_id'])
y = train.y
X_test = test.drop(columns=['sample_id'])

X_all = X.append(X_test)

# %%
''' Gather all preprocessing functions '''

from sklearn.preprocessing import FunctionTransformer
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import bisect
from scipy.stats import shapiro
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM


''' 1 - divide to training and holdout datasets '''

X_train, X_hold, y_train, y_hold = train_test_split(X, y, random_state=3, test_size=0.3)

''' 2 - define the same validation scheme for all models '''

skf = RepeatedStratifiedKFold(n_repeats=5, random_state=17)


''' Function 1 - delete all columns with NaN or Inf '''
columns_to_keep = X_all.replace([np.inf, -np.inf], np.nan).dropna(axis=1).columns

def del_nan(x):
    return x[columns_to_keep]
delete_nan = FunctionTransformer(del_nan, validate=False)


''' Function 2 - delete NaN-only columns '''

na_cols = X_all[X_all.isna().any()[lambda x: x].index].isna().agg(['sum', 'count']).T

all_na_cols = na_cols[na_cols['sum'] == na_cols['count']]

def drop_all_na(X):
    ''' Here we drop all columns which consist of NaN only '''
    idx = all_na_cols.index.values
    return X.drop(columns=idx)

drop_all_na_f = FunctionTransformer(drop_all_na, validate=False)


''' Function 3 - replace NaN '''

has_na_cols = na_cols.T.drop(columns=all_na_cols.index.values).T
has_na_cols['perc'] = has_na_cols['sum']/has_na_cols['count']

'''def replace_na(X, add_boolean=True, threshold=0.3):
    Here we apply two filling strategies
            for two types of columns with na:
            % na > threshold - fill with mean
            % na < threshold - fill with 0.
        Plus we add additional columns showing
            if the value was na before transformation.
    X_copy = X.copy()
    cols_less = has_na_cols[has_na_cols['perc'] < threshold].index.values
    cols_more = has_na_cols[has_na_cols['perc'] >= threshold].index.values
    X_less = X_copy[cols_less]
    X_less = X_less.fillna(X_less.mean())
    X_copy[cols_less] = X_less
    X_copy[cols_more] = X_more
    if add_boolean:
        was_na = X[has_na_cols.index.values].isna().astype('int64')
        was_na.columns = was_na.columns.map(lambda x: x + '_na')
        X_copy = pd.concat([X_copy, was_na], axis=1)
    return X_copy'''
    
# I should have checked columns for categorical features before

def replace_na(X, add_boolean=True):
    ''' Here we apply mean filling strategy.
        And add additional columns showing if the values
        was na before transformation.
    '''
    X_copy = X.copy()
    cols = has_na_cols.index.values
    X_c = X_copy[cols]
    X_c = X_c.fillna(X_all.replace([np.inf, -np.inf], np.nan).mean())
    X_copy[cols] = X_c
    if add_boolean:
        was_na = X[has_na_cols.index.values].isna().astype('int64')
        was_na.columns = was_na.columns.map(lambda x: x + '_na')
        X_copy = pd.concat([X_copy, was_na], axis=1)
    return X_copy

replace_na_f = FunctionTransformer(replace_na, validate=False)


''' Function 4 - replace inf '''

pos_inf_cols = X_all.fillna(0).replace([np.inf], 
                                       np.nan).isna().any()[lambda x: x].index
pos_inf_cols = X_all[pos_inf_cols].replace([np.inf], 
                                           np.nan).isna().agg(['sum', 'count']).T
neg_inf_cols = X_all.fillna(0).replace([-np.inf],
                                       np.nan).isna().any()[lambda x: x].index

def fill_inf(X, add_boolean=True, multiplier=2):
    '''
    Here we apply filling strategy for infinite values:
        we replace it with absolute maximum value * multiplier.
    Additionally, we new columns showing if the value
        was infinite before filling.
    '''
    X_copy = X.copy()
    X_pos = X_copy[pos_inf_cols.index.values]
    to_fill = X_pos.replace(np.inf, np.nan).abs().max() * multiplier + 1.0
    X_pos = X_pos.replace(np.inf, np.nan).fillna(to_fill)
    X_copy[pos_inf_cols.index.values] = X_pos
    if add_boolean:
        was_inf = X[pos_inf_cols.index.values].replace(np.inf, np.nan).isna().astype('int64')
        was_inf.columns = was_inf.columns.map(lambda x: x + '_inf')
        X_copy = pd.concat([X_copy, was_inf], axis=1)
    return X_copy

fill_inf_f = FunctionTransformer(fill_inf, validate=False)


''' First block of data cleaning is gathered in one function '''

def pre_proc(X):
    return fill_inf(replace_na(drop_all_na(X)))


''' Function and class 5 - delete zero-variance features '''

w = fill_inf(replace_na(drop_all_na(X_all))).var()
zero_var_cols = w[np.isclose(w, 0)]

def drop_zero_var(X):
    idx = zero_var_cols.index.values
    return X.drop(columns=idx)

drop_zero_var_f = FunctionTransformer(drop_zero_var)

class Drop_zero_var:
    def __init__(self):
        self.zero_var_cols = []
        self.is_fitted = False
        
    def fit(self, X, y=None):
        w = X.var()
        self.zero_var_cols = w[np.isclose(w, 0.0)].index.values
        self.is_fitted = True
        return self
    
    def transform(self, X, y=None):
        X_copy = X.copy()
        return X_copy.drop(columns=self.zero_var_cols)
    
    def fit_transform(self, X, y=None):
        if not self.is_fitted:
            self.fit(X, y)
        return self.transform(X, y)

print(Drop_zero_var().fit_transform(pre_proc(X_train), y_train).shape)

''' Function and class 6 - drop highly correlated features '''

'''
# Here is the function
print(drop_zero_var(pre_proc(X_all)).shape)
corr_matrix = pre_proc(X_all).corr().abs()
print(corr_matrix.shape)

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
print(len(to_drop))

'''

class Drop_corr:
    def __init__(self, threshold=0.95):
        self.to_drop = []
        self.is_fitted = False
        self.threshold = threshold
        
    def fit(self, X, y=None):
        corr_matrix = X.corr().abs()
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
        self.to_drop = [column for column in upper.columns if any(upper[column] > self.threshold)]
        self.is_fitted = True
        return self
    
    def transform(self, X, y=None):
        X_copy = X.copy()
        return X_copy.drop(columns=self.to_drop)
    
    def fit_transform(self, X, y=None):
        if not self.is_fitted:
            self.fit(X, y)
        return self.transform(X, y)

print(Drop_corr().fit_transform(pre_proc(X_train), y_train).shape)
    
''' Class 7 - encode categorical labels '''

class LE_df:
    def __init__(self, threshold=5):
        self.le_dict = {}
        self.threshold = threshold
        
    def fit(self, X, y=None):
        X_copy = X.copy()
        counts = X_copy.apply(lambda x: x.value_counts().shape[0])
        categorical = X_copy[counts[counts <= self.threshold].index]
        for col in categorical.columns:
            le = LabelEncoder()
            le.fit(categorical[col])
            self.le_dict[col] = le
        return self
    
    def transform(self, X, y=None):
        X_copy = X.copy()
        for col in self.le_dict.keys():
            X_copy[col] = X_copy[col].map(lambda s: -100500 if s not in \
                                          self.le_dict[col].classes_ else s)
            if np.any(X_copy[col]==-100500):
                le_classes = self.le_dict[col].classes_.tolist()
                le_classes.append(-100500)
                self.le_dict[col].classes_ = np.asarray(le_classes)
            X_copy[col] = self.le_dict[col].transform(X_copy[col])
        return X_copy
    
    def fit_transform(self, X, y=None):
        self.fit(X)
        return self.transform(X)

print(LE_df().fit_transform(pre_proc(X_train), y_train).shape)
    
''' Class 8 - target mean encode categorical labels '''

class LOOTME_df:
    ''' Class performs leave-one-out target mean encoding '''
    def __init__(self, threshold=5):
        self.threshold = threshold
        self.tme_dict = {}
        self.is_fitted = False
        
    def fit(self, X, y):
        X_copy = X.copy()
        y_copy = y.copy()
        counts = X_copy.apply(lambda x: x.value_counts().shape[0])
        categorical = X_copy[counts[counts <= self.threshold].index]
        for col in categorical.columns:
            df = pd.concat((X_copy[col], y_copy), axis=1)
            df.columns = ['col', 'y']
            tme = {}
            for value in df['col'].unique():
                y_val = df[df['col'] == value]['y'].values
                col_val = df[df['col'] == value]['col'].values
                loo_mean = np.mean((np.full_like(col_val, y_val.sum()) - y_val) / y_val.shape[0])
                tme[value] = loo_mean
            self.tme_dict[col] = tme
        self.is_fitted = True
        return self
    
    def transform(self, X, y=None):
        X_copy = X.copy()
        for col in self.tme_dict.keys():
            X_copy[col] = X_copy[col].map(lambda s: -100500 if s not in self.tme_dict[col].keys() else s)
            self.tme_dict[col][-100500] = 0.0
            X_copy[col] = X_copy[col].map(self.tme_dict[col])
        return X_copy
        
    
    def fit_transform(self, X, y):
        if not self.is_fitted:
            self.fit(X, y)
        return self.transform(X, y)
    
print(LOOTME_df().fit_transform(pre_proc(X_train), y_train).shape)


''' Class 9 - One Hot Encoding of categorical features '''

class OneHot_df:
    def __init__(self, threshold=5, drop_collinear=False):
        self.threshold = threshold
        self.drop_collinear = drop_collinear
        self.categorical = []
        self.ohe = None
        self.column_names = None
        self.is_fitted = False
        
    def fit(self, X, y=None):
        X_copy = X.copy()
        counts = X_copy.apply(lambda x: x.value_counts().shape[0])
        X_cat = X_copy[counts[(counts <= self.threshold) & (counts > 1)].index]
        ohe = OneHotEncoder(handle_unknown='ignore')
        ohe.fit(X_cat)
        self.categorical = X_cat.columns
        self.ohe = ohe
        self.is_fitted = True
        return self
    
    def transform(self, X, y=None):
        X_copy = X.copy()
        X_cat = X_copy.copy()[self.categorical]
        X_cat_tr = self.ohe.transform(X_cat).toarray()
        if not self.column_names:
            column_names = []
            for i, col in enumerate(self.categorical):
                column_names.extend([col + '_' + str(s) for s in self.ohe.categories_[i]])
            self.column_names = column_names
        X_cat_tr = pd.DataFrame(X_cat_tr, columns=self.column_names, index=X_copy.index)
        X_other = X_copy.drop(columns=self.categorical)
        X_copy = pd.concat([X_other, X_cat_tr], axis=1)
        if self.drop_collinear:
            to_drop = pd.Series(self.column_names, 
        index=self.column_names).apply(lambda x: x.endswith('_0'))[lambda x: x].index
            X_copy.drop(columns=to_drop)
        return X_copy
    
    def fit_transform(self, X, y=None):
        if not self.is_fitted:
            self.fit(X, y)
        return self.transform(X, y)

print(OneHot_df().fit(pre_proc(X_train)).transform(pre_proc(X_hold)).shape)

''' Class 10 - find best normalizing transformation '''

def get_shapiro_p(X):
    _, p = shapiro(X)
    return p

class Find_Trans:
    def __init__(self, threshold=10):
        self.threshold = threshold
        self.pvals = []
        self.numerical = []
        self.is_fitted = False
        self.mms = MinMaxScaler()
        self.trans_dict = {'no': lambda x: x,
                           'x^2': lambda x: np.power(x, 2), 
                           'x^3': lambda x: np.power(x, 3), 
                           'log(x)': lambda x: np.log(x), 
                           #'exp(x)': lambda x: np.exp(x/10), 
                           'sqrt(x)': lambda x: np.sqrt(x)}
    
    def fit(self, X, y=None):
        X_copy = X.copy()
        counts = X_copy.apply(lambda x: x.value_counts().shape[0])
        self.numerical = counts[counts > self.threshold].index.values
        X_numer = X_copy[self.numerical]
        idx = X_numer.index
        X_numer = pd.DataFrame(self.mms.fit_transform(X_numer) + 0.01,
                               columns=self.numerical,
                               index=idx)
        pvals = pd.DataFrame(X_numer.apply(get_shapiro_p), columns=['no'])
        for name in self.trans_dict.keys():
            if name not in pvals.columns:
                pvals[name] = X_numer.apply(self.trans_dict[name]).apply(get_shapiro_p)
        self.pvals = pvals
        self.is_fitted = True
        return self
    
    def transform(self, X, y=None):
        X_copy = X.copy()
        X_numer = X_copy[self.numerical]
        idx = X_numer.index
        X_numer = pd.DataFrame(self.mms.transform(X_numer) + 0.01,
                               columns=self.numerical,
                               index=idx)
        best_transform = self.pvals.idxmax(axis=1)
        best_transform = best_transform.map(self.trans_dict).to_dict()
        X_numer = X_numer.apply(best_transform)
        X_numer = X_numer.fillna(X_numer.min()-1)
        for col in self.numerical:
            X_copy[col] = X_numer[col]
        return X_copy
    
    def fit_transform(self, X, y=None):
        if not self.is_fitted:
            self.fit(X, y)
        return self.transform(X, y)

print(Find_Trans().fit(pre_proc(X_train), y_train).transform(pre_proc(X_hold)).shape)


''' Class 11 - find and drop outliers '''

class DetectOut_df:
    def __init__(self, method='IsolationForest', out_fraction=0.05, 
                 drop=True, random_state=17,
                 kernel='rbf', shrink=True):
        self.method = method
        self.out_fraction = out_fraction
        self.drop = drop
        self.is_fitted = False
        self.random_state = random_state
        self.kernel = kernel
        self.shrink = shrink
        self.model = None
        self.train_set = []
        
    def fit(self, X, y=None):
        if self.method == 'IsolationForest':
            model = IsolationForest(random_state=self.random_state,
                        n_estimators=100,
                        max_features=0.9,
                        contamination=self.out_fraction, #
                        n_jobs=-1,
                        behaviour='new')
        if self.method == 'OneClassSVM':
            model = OneClassSVM(kernel=self.kernel,
                     nu=self.out_fraction,
                     shrinking=self.shrink,
                     gamma='scale'
                    )
        model.fit(X, y)
        self.model = model
        self.is_fitted = True
        self.train_set = X.copy()
        return self
    
    def transform(self, X, y):
        ''' We shouldn't predict any outliers for test set '''
        X_copy = X.copy()
        X_copy['outlier'] = 1
        X_copy['y'] = y.copy()
        if self.train_set.equals(X):
            X_copy['outlier'] = self.model.predict(X)
        if self.drop:
            X_copy = X_copy[X_copy['outlier'] == 1]
            X_copy = X_copy.drop(columns=['outlier'])
        y_copy = X_copy['y']
        X_copy = X_copy.drop(columns=['y'])
        return X_copy, y_copy
    
    def fit_transform(self, X, y):
        if not self.is_fitted:
            self.fit(X, y)
        return self.transform(X, y)
    
print(DetectOut_df().fit_transform(pre_proc(X_train), y_train)[0].shape)
# Out:
# (766, 1777)
# (766, 932)
# (766, 1908)
# (766, 1908)
# (329, 2518)
# (329, 1908)
# (727, 1908)

# %% [markdown]
# # Базовый CatBoost

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score

cat = CatBoostClassifier(learning_rate=0.001, 
                                                iterations=500,
                                                loss_function='CrossEntropy',
                                                custom_metric='AUC:hints=skip_train~false',
                                                eval_metric='AUC:hints=skip_train~false',
                                                random_state=17,
                                                rsm=0.1,
                                                bootstrap_type='Bernoulli',
                                                subsample=0.9,
                                                verbose=100)
pipe_cat = Pipeline([('drop_na', delete_nan),
                     ('cat', cat)])

pipe_cat.fit(X_train, y_train)

#scores = cross_val_score(pipe_cat, X_train, y_train, cv=skf, scoring='roc_auc')

print('Train ROC AUC: %.4f' % roc_auc_score(y_train, pipe_cat.predict_proba(X_train)[:,1]))
#print('Cross-validation ROC AUC: mean %.4f, std %.4f' % (scores.mean(), scores.std()))
print('Holdout ROC AUC: %.4f' % roc_auc_score(y_hold, pipe_cat.predict_proba(X_hold)[:,1]))
# Out:
# 0:	learn: 0.8060754	total: 30.2ms	remaining: 15.1s
# 100:	learn: 0.8924454	total: 3.38s	remaining: 13.4s
# 200:	learn: 0.8949478	total: 6.55s	remaining: 9.75s
# 300:	learn: 0.8966257	total: 9.98s	remaining: 6.6s
# 400:	learn: 0.8992141	total: 13s	remaining: 3.21s
# 499:	learn: 0.9012720	total: 16.1s	remaining: 0us
# Train ROC AUC: 0.9013
# Holdout ROC AUC: 0.8191

# %% [markdown]
# ## После трансформации фич

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score

CORR_THRESHOLD = 0.94
CAT_THRESHOLD = 5 # <- and less unique values make feature categorical

cat = CatBoostClassifier(learning_rate=0.001, 
                                                iterations=500,
                                                loss_function='CrossEntropy',
                                                custom_metric='AUC:hints=skip_train~false',
                                                eval_metric='AUC:hints=skip_train~false',
                                                random_state=17,
                                                rsm=0.1,
                                                bootstrap_type='Bernoulli',
                                                subsample=0.9,
                                                verbose=100)
pipe_cat = Pipeline([('pre_proc', FunctionTransformer(pre_proc, validate=False)),
                      ('drop_zero_var', Drop_zero_var()),
                      ('drop_corr', Drop_corr(threshold=CORR_THRESHOLD)),
                      ('lootme', LOOTME_df(threshold=CAT_THRESHOLD)),
                      ('transform', Find_Trans(threshold=CAT_THRESHOLD)),
                     ('cat', cat)])

pipe_cat.fit(X_train, y_train)

#scores = cross_val_score(pipe_cat, X_train, y_train, cv=skf, scoring='roc_auc')

print('Train ROC AUC: %.4f' % roc_auc_score(y_train, pipe_cat.predict_proba(X_train)[:,1]))
#print('Cross-validation ROC AUC: mean %.4f, std %.4f' % (scores.mean(), scores.std()))
print('Holdout ROC AUC: %.4f' % roc_auc_score(y_hold, pipe_cat.predict_proba(X_hold)[:,1]))
# Out:
# 0:	learn: 0.7889527	total: 27ms	remaining: 13.5s
# 100:	learn: 0.8905381	total: 2.92s	remaining: 11.6s
# 200:	learn: 0.8959516	total: 6.2s	remaining: 9.22s
# 300:	learn: 0.8985831	total: 8.78s	remaining: 5.8s
# 400:	learn: 0.9017381	total: 11.4s	remaining: 2.81s
# 499:	learn: 0.9048930	total: 14s	remaining: 0us
# Train ROC AUC: 0.9049
# Holdout ROC AUC: 0.8198

# %%
pipe_cat.fit(X, y)

submission = pd.read_csv(submission_file)
submission['y'] = pipe_cat.predict_proba(X_test)[:,1]
submission.to_csv('submission_cat_transform.csv', index=False)
# Out:
# 0:	learn: 0.7877042	total: 26.2ms	remaining: 13.1s
# 100:	learn: 0.8896817	total: 3.84s	remaining: 15.2s
# 200:	learn: 0.8913231	total: 6.82s	remaining: 10.2s
# 300:	learn: 0.8931157	total: 10.2s	remaining: 6.75s
# 400:	learn: 0.8954426	total: 13s	remaining: 3.2s
# 499:	learn: 0.8980190	total: 16.4s	remaining: 0us

# %% [markdown]
# ## Финальная модель - 0.88414

# %%
# %%time
''' Let's finally play with Catboost '''

from sklearn.feature_selection import SelectKBest, f_classif
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score

CORR_THRESHOLD = 0.94
CAT_THRESHOLD = 5 # <- and less unique values make feature categorical
#OUT_FRACTION = 0.05 # <- percent of outliers
#K = 400
L2_LEAF_REG = 0.5 # <- regularization coefficient for CatBoost
DEPTH = 10 # <- max tree depth for Catboost, can't be >10, or kernel will just die

cat = CatBoostClassifier(learning_rate=0.001, 
                         iterations=500,
                         loss_function='CrossEntropy',
                         l2_leaf_reg=L2_LEAF_REG,
                         depth=DEPTH,
                         custom_metric='AUC:hints=skip_train~false', #CPU-only
                         eval_metric='AUC:hints=skip_train~false', #CPU-only
                         random_state=17,
                         rsm=0.1, #CPU-only
                         bootstrap_type='Bernoulli',
                         subsample=0.9,
                         #task_type='GPU',
                         verbose=100)
pipe_cat = Pipeline([('pre_proc', FunctionTransformer(pre_proc, validate=False)),
                      ('drop_zero_var', Drop_zero_var()),
                      ('drop_corr', Drop_corr(threshold=CORR_THRESHOLD)),
                      ('lootme', LOOTME_df(threshold=CAT_THRESHOLD)),
                      ('transform', Find_Trans(threshold=CAT_THRESHOLD)),
                      #('feat_sel', SelectKBest(f_classif, K)),
                      ('cat', cat)])

pipe_cat.fit(X_train, y_train)

#scores = cross_val_score(pipe_cat, X_train, y_train, cv=skf, scoring='roc_auc')

print('Train ROC AUC: %.4f' % roc_auc_score(y_train, pipe_cat.predict_proba(X_train)[:,1]))
#print('Cross-validation ROC AUC: mean %.4f, std %.4f' % (scores.mean(), scores.std()))
print('Holdout ROC AUC: %.4f' % roc_auc_score(y_hold, pipe_cat.predict_proba(X_hold)[:,1]))
# Out:
# 0:	learn: 0.8183259	total: 278ms	remaining: 2m 18s
# 100:	learn: 0.9601761	total: 33.6s	remaining: 2m 12s
# 200:	learn: 0.9649228	total: 1m	remaining: 1m 29s
# 300:	learn: 0.9673679	total: 1m 31s	remaining: 1m
# 400:	learn: 0.9700640	total: 2m 12s	remaining: 32.6s
# 499:	learn: 0.9722581	total: 2m 53s	remaining: 0us
# Train ROC AUC: 0.9723
# Holdout ROC AUC: 0.8433
# CPU times: user 7min 27s, sys: 38.3 s, total: 8min 5s
# Wall time: 3min 11s

# %%
pipe_cat.fit(X, y)

submission = pd.read_csv(submission_file)
submission['y'] = pipe_cat.predict_proba(X_test)[:,1]
submission.to_csv('submission_cat_modified.csv', index=False)
# Out:
# 0:	learn: 0.8581760	total: 400ms	remaining: 3m 19s
# 100:	learn: 0.9522713	total: 42.5s	remaining: 2m 47s
# 200:	learn: 0.9557651	total: 1m 28s	remaining: 2m 10s
# 300:	learn: 0.9581447	total: 2m 11s	remaining: 1m 27s
# 400:	learn: 0.9607246	total: 2m 53s	remaining: 42.9s
# 499:	learn: 0.9631394	total: 3m 27s	remaining: 0us

# %% [markdown]
# # Попробуем обучить поглубже

# %%
# %%time
''' Let's finally play with Catboost '''

from sklearn.feature_selection import SelectKBest, f_classif
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score

CORR_THRESHOLD = 0.94
CAT_THRESHOLD = 5 # <- and less unique values make feature categorical
#OUT_FRACTION = 0.05 # <- percent of outliers
#K = 400
L2_LEAF_REG = 0.5 # <- regularization coefficient for CatBoost
DEPTH = 12 # <- max tree depth for Catboost, can't be >10, or kernel will just die

cat = CatBoostClassifier(learning_rate=0.001, 
                         iterations=500,
                         loss_function='CrossEntropy',
                         l2_leaf_reg=L2_LEAF_REG,
                         depth=DEPTH,
                         custom_metric='AUC:hints=skip_train~false', #CPU-only
                         eval_metric='AUC:hints=skip_train~false', #CPU-only
                         random_state=17,
                         rsm=0.1, #CPU-only
                         bootstrap_type='Bernoulli',
                         subsample=0.9,
                         #task_type='GPU',
                         verbose=1)
pipe_cat = Pipeline([('pre_proc', FunctionTransformer(pre_proc, validate=False)),
                      ('drop_zero_var', Drop_zero_var()),
                      ('drop_corr', Drop_corr(threshold=CORR_THRESHOLD)),
                      ('lootme', LOOTME_df(threshold=CAT_THRESHOLD)),
                      ('transform', Find_Trans(threshold=CAT_THRESHOLD)),
                      #('feat_sel', SelectKBest(f_classif, K)),
                      ('cat', cat)])

pipe_cat.fit(X_train, y_train)

#scores = cross_val_score(pipe_cat, X_train, y_train, cv=skf, scoring='roc_auc')

print('Train ROC AUC: %.4f' % roc_auc_score(y_train, pipe_cat.predict_proba(X_train)[:,1]))
#print('Cross-validation ROC AUC: mean %.4f, std %.4f' % (scores.mean(), scores.std()))
print('Holdout ROC AUC: %.4f' % roc_auc_score(y_hold, pipe_cat.predict_proba(X_hold)[:,1]))
# Out:
# 0:	learn: 0.8372878	total: 1.23s	remaining: 10m 16s
# 1:	learn: 0.9261853	total: 2.77s	remaining: 11m 30s
# 2:	learn: 0.9283148	total: 3.95s	remaining: 10m 54s
# 3:	learn: 0.9532711	total: 5.3s	remaining: 10m 57s
# 4:	learn: 0.9618611	total: 6.76s	remaining: 11m 9s
# 5:	learn: 0.9637684	total: 8.16s	remaining: 11m 12s
# 6:	learn: 0.9620117	total: 9.4s	remaining: 11m 2s
# 7:	learn: 0.9637326	total: 10.8s	remaining: 11m 4s
# 8:	learn: 0.9659446	total: 12.1s	remaining: 11m
# 9:	learn: 0.9658550	total: 13.4s	remaining: 10m 57s
# 10:	learn: 0.9685940	total: 14.7s	remaining: 10m 55s
# 11:	learn: 0.9690529	total: 16s	remaining: 10m 49s
# 12:	learn: 0.9684076	total: 17.3s	remaining: 10m 48s
# 13:	learn: 0.9671456	total: 18.6s	remaining: 10m 45s
# 14:	learn: 0.9680563	total: 19.7s	remaining: 10m 37s
# 15:	learn: 0.9684506	total: 21s	remaining: 10m 35s
# 16:	learn: 0.9671385	total: 21.1s	remaining: 10m
# 17:	learn: 0.9692465	total: 22.8s	remaining: 10m 10s
# 18:	learn: 0.9687446	total: 24.6s	remaining: 10m 22s
# 19:	learn: 0.9683933	total: 25.8s	remaining: 10m 20s
# 20:	learn: 0.9698919	total: 27.2s	remaining: 10m 20s
# 21:	learn: 0.9708742	total: 28.7s	remaining: 10m 22s
# 22:	learn: 0.9717848	total: 29.9s	remaining: 10m 20s
# 23:	learn: 0.9717848	total: 31.3s	remaining: 10m 19s
# 24:	learn: 0.9714765	total: 32.7s	remaining: 10m 20s
# 25:	learn: 0.9742299	total: 34.1s	remaining: 10m 21s
# 26:	learn: 0.9757428	total: 35.5s	remaining: 10m 21s
# 27:	learn: 0.9747677	total: 36.8s	remaining: 10m 20s
# 28:	learn: 0.9760440	total: 37.9s	remaining: 10m 15s
# 29:	learn: 0.9762806	total: 39.3s	remaining: 10m 15s
# 30:	learn: 0.9777577	total: 40.5s	remaining: 10m 13s
# 31:	learn: 0.9774996	total: 41.7s	remaining: 10m 10s
# 32:	learn: 0.9768901	total: 42.2s	remaining: 9m 57s
# 33:	learn: 0.9776573	total: 43.5s	remaining: 9m 56s
# 34:	learn: 0.9770263	total: 44.9s	remaining: 9m 56s
# 35:	learn: 0.9764670	total: 46.2s	remaining: 9m 54s
# 36:	learn: 0.9759508	total: 47.6s	remaining: 9m 55s
# 37:	learn: 0.9762304	total: 48.6s	remaining: 9m 51s
# 38:	learn: 0.9758432	total: 50s	remaining: 9m 50s
# 39:	learn: 0.9764814	total: 51.4s	remaining: 9m 51s
# 40:	learn: 0.9768542	total: 52.8s	remaining: 9m 50s
# 41:	learn: 0.9762950	total: 54.1s	remaining: 9m 49s
# 42:	learn: 0.9766606	total: 55.4s	remaining: 9m 48s
# 43:	learn: 0.9762806	total: 56.8s	remaining: 9m 48s
# 44:	learn: 0.9771626	total: 58.7s	remaining: 9m 53s
# 45:	learn: 0.9773490	total: 1m	remaining: 9m 53s
# 46:	learn: 0.9769044	total: 1m 1s	remaining: 9m 53s
# 47:	learn: 0.9767467	total: 1m 2s	remaining: 9m 53s
# 48:	learn: 0.9768686	total: 1m 4s	remaining: 9m 53s
# 49:	learn: 0.9769044	total: 1m 6s	remaining: 9m 56s
# 50:	learn: 0.9766606	total: 1m 7s	remaining: 9m 57s
# 51:	learn: 0.9775426	total: 1m 9s	remaining: 9m 58s
# 52:	learn: 0.9773705	total: 1m 10s	remaining: 9m 58s
# 53:	learn: 0.9769259	total: 1m 12s	remaining: 9m 58s
# 54:	learn: 0.9773777	total: 1m 13s	remaining: 9m 57s
# 55:	learn: 0.9770263	total: 1m 15s	remaining: 9m 56s
# 56:	learn: 0.9765889	total: 1m 16s	remaining: 9m 55s
# 57:	learn: 0.9776501	total: 1m 18s	remaining: 9m 55s
# 58:	learn: 0.9783457	total: 1m 19s	remaining: 9m 56s
# 59:	learn: 0.9782094	total: 1m 21s	remaining: 9m 54s
# 60:	learn: 0.9778581	total: 1m 21s	remaining: 9m 44s
# 61:	learn: 0.9779370	total: 1m 22s	remaining: 9m 44s
# 62:	learn: 0.9776645	total: 1m 24s	remaining: 9m 43s
# 63:	learn: 0.9776645	total: 1m 25s	remaining: 9m 41s
# 64:	learn: 0.9775569	total: 1m 26s	remaining: 9m 39s
# 65:	learn: 0.9773705	total: 1m 27s	remaining: 9m 38s
# 66:	learn: 0.9779370	total: 1m 29s	remaining: 9m 36s
# 67:	learn: 0.9776860	total: 1m 30s	remaining: 9m 35s
# 68:	learn: 0.9781377	total: 1m 31s	remaining: 9m 34s
# 69:	learn: 0.9787185	total: 1m 33s	remaining: 9m 32s
# 70:	learn: 0.9785106	total: 1m 33s	remaining: 9m 24s
# 71:	learn: 0.9781306	total: 1m 34s	remaining: 9m 19s
# 72:	learn: 0.9780517	total: 1m 35s	remaining: 9m 19s
# 73:	learn: 0.9781521	total: 1m 36s	remaining: 9m 18s
# 74:	learn: 0.9787615	total: 1m 38s	remaining: 9m 17s
# 75:	learn: 0.9788117	total: 1m 39s	remaining: 9m 16s
# 76:	learn: 0.9784532	total: 1m 41s	remaining: 9m 15s
# 77:	learn: 0.9779872	total: 1m 41s	remaining: 9m 7s
# 78:	learn: 0.9780445	total: 1m 42s	remaining: 9m 7s
# 79:	learn: 0.9779943	total: 1m 44s	remaining: 9m 8s
# 80:	learn: 0.9779370	total: 1m 45s	remaining: 9m 7s
# 81:	learn: 0.9778366	total: 1m 47s	remaining: 9m 8s
# 82:	learn: 0.9780517	total: 1m 49s	remaining: 9m 8s
# 83:	learn: 0.9777936	total: 1m 50s	remaining: 9m 8s
# 84:	learn: 0.9777290	total: 1m 52s	remaining: 9m 9s
# 85:	learn: 0.9774494	total: 1m 54s	remaining: 9m 10s
# 86:	learn: 0.9773203	total: 1m 55s	remaining: 9m 10s
# 87:	learn: 0.9775426	total: 1m 57s	remaining: 9m 9s
# 88:	learn: 0.9776000	total: 1m 58s	remaining: 9m 7s
# 89:	learn: 0.9775139	total: 2m	remaining: 9m 10s
# 90:	learn: 0.9778724	total: 2m 2s	remaining: 9m 10s
# 91:	learn: 0.9777864	total: 2m 4s	remaining: 9m 13s
# 92:	learn: 0.9779083	total: 2m 6s	remaining: 9m 14s
# 93:	learn: 0.9777936	total: 2m 9s	remaining: 9m 17s
# 94:	learn: 0.9777434	total: 2m 10s	remaining: 9m 16s
# 95:	learn: 0.9783887	total: 2m 12s	remaining: 9m 16s
# 96:	learn: 0.9783385	total: 2m 13s	remaining: 9m 15s
# 97:	learn: 0.9783528	total: 2m 15s	remaining: 9m 14s
# 98:	learn: 0.9783959	total: 2m 16s	remaining: 9m 13s
# 99:	learn: 0.9783528	total: 2m 18s	remaining: 9m 12s
# 100:	learn: 0.9783098	total: 2m 19s	remaining: 9m 10s
# 101:	learn: 0.9782668	total: 2m 20s	remaining: 9m 9s
# 102:	learn: 0.9780517	total: 2m 22s	remaining: 9m 8s
# 103:	learn: 0.9782740	total: 2m 23s	remaining: 9m 6s
# 104:	learn: 0.9786898	total: 2m 25s	remaining: 9m 5s
# 105:	learn: 0.9786253	total: 2m 26s	remaining: 9m 4s
# 106:	learn: 0.9783385	total: 2m 27s	remaining: 9m 3s
# 107:	learn: 0.9782094	total: 2m 29s	remaining: 9m 1s
# 108:	learn: 0.9783026	total: 2m 30s	remaining: 9m
# 109:	learn: 0.9783457	total: 2m 31s	remaining: 8m 58s
# 110:	learn: 0.9784389	total: 2m 33s	remaining: 8m 58s
# 111:	learn: 0.9785321	total: 2m 35s	remaining: 8m 57s
# 112:	learn: 0.9785966	total: 2m 36s	remaining: 8m 57s
# 113:	learn: 0.9786181	total: 2m 38s	remaining: 8m 56s
# 114:	learn: 0.9787257	total: 2m 40s	remaining: 8m 56s
# 115:	learn: 0.9786396	total: 2m 41s	remaining: 8m 54s
# 116:	learn: 0.9786396	total: 2m 42s	remaining: 8m 53s
# 117:	learn: 0.9789551	total: 2m 44s	remaining: 8m 52s
# 118:	learn: 0.9795503	total: 2m 45s	remaining: 8m 51s
# 119:	learn: 0.9798514	total: 2m 47s	remaining: 8m 49s
# 120:	learn: 0.9796865	total: 2m 48s	remaining: 8m 47s
# 121:	learn: 0.9796005	total: 2m 49s	remaining: 8m 45s
# 122:	learn: 0.9797295	total: 2m 51s	remaining: 8m 44s
# 123:	learn: 0.9799016	total: 2m 52s	remaining: 8m 42s
# 124:	learn: 0.9805900	total: 2m 53s	remaining: 8m 41s
# 125:	learn: 0.9807907	total: 2m 55s	remaining: 8m 39s
# 126:	learn: 0.9807907	total: 2m 56s	remaining: 8m 37s
# 127:	learn: 0.9806473	total: 2m 57s	remaining: 8m 36s
# 128:	learn: 0.9805685	total: 2m 59s	remaining: 8m 35s
# 129:	learn: 0.9804681	total: 3m	remaining: 8m 34s
# 130:	learn: 0.9804394	total: 3m 2s	remaining: 8m 33s
# 131:	learn: 0.9805039	total: 3m 3s	remaining: 8m 31s
# 132:	learn: 0.9805111	total: 3m 4s	remaining: 8m 27s
# 133:	learn: 0.9806115	total: 3m 5s	remaining: 8m 26s
# 134:	learn: 0.9806545	total: 3m 6s	remaining: 8m 24s
# 135:	learn: 0.9805828	total: 3m 7s	remaining: 8m 20s
# 136:	learn: 0.9806545	total: 3m 8s	remaining: 8m 19s
# 137:	learn: 0.9806760	total: 3m 9s	remaining: 8m 17s
# 138:	learn: 0.9806043	total: 3m 11s	remaining: 8m 16s
# 139:	learn: 0.9806832	total: 3m 12s	remaining: 8m 14s
# 140:	learn: 0.9806115	total: 3m 13s	remaining: 8m 12s
# 141:	learn: 0.9807334	total: 3m 14s	remaining: 8m 11s
# 142:	learn: 0.9805685	total: 3m 14s	remaining: 8m 6s
# 143:	learn: 0.9807405	total: 3m 16s	remaining: 8m 5s
# 144:	learn: 0.9807549	total: 3m 17s	remaining: 8m 4s
# 145:	learn: 0.9808409	total: 3m 19s	remaining: 8m 2s
# 146:	learn: 0.9807334	total: 3m 19s	remaining: 7m 58s
# 147:	learn: 0.9808983	total: 3m 20s	remaining: 7m 56s
# 148:	learn: 0.9807262	total: 3m 21s	remaining: 7m 55s
# 149:	learn: 0.9809915	total: 3m 22s	remaining: 7m 53s
# 150:	learn: 0.9808338	total: 3m 24s	remaining: 7m 52s
# 151:	learn: 0.9811923	total: 3m 25s	remaining: 7m 51s
# 152:	learn: 0.9811994	total: 3m 27s	remaining: 7m 50s
# 153:	learn: 0.9811779	total: 3m 28s	remaining: 7m 49s
# 154:	learn: 0.9813859	total: 3m 30s	remaining: 7m 48s
# 155:	learn: 0.9815078	total: 3m 31s	remaining: 7m 46s
# 156:	learn: 0.9812568	total: 3m 33s	remaining: 7m 45s
# 157:	learn: 0.9813787	total: 3m 34s	remaining: 7m 44s
# 158:	learn: 0.9815508	total: 3m 36s	remaining: 7m 43s
# 159:	learn: 0.9815149	total: 3m 37s	remaining: 7m 42s
# 160:	learn: 0.9816799	total: 3m 39s	remaining: 7m 41s
# 161:	learn: 0.9817372	total: 3m 40s	remaining: 7m 40s
# 162:	learn: 0.9818519	total: 3m 42s	remaining: 7m 39s
# 163:	learn: 0.9819380	total: 3m 43s	remaining: 7m 38s
# 164:	learn: 0.9818878	total: 3m 44s	remaining: 7m 36s
# 165:	learn: 0.9818304	total: 3m 46s	remaining: 7m 35s
# 166:	learn: 0.9818089	total: 3m 47s	remaining: 7m 34s
# 167:	learn: 0.9816655	total: 3m 49s	remaining: 7m 32s
# 168:	learn: 0.9818663	total: 3m 50s	remaining: 7m 31s
# 169:	learn: 0.9822678	total: 3m 51s	remaining: 7m 29s
# 170:	learn: 0.9820957	total: 3m 52s	remaining: 7m 28s
# 171:	learn: 0.9822176	total: 3m 54s	remaining: 7m 26s
# 172:	learn: 0.9823467	total: 3m 55s	remaining: 7m 25s
# 173:	learn: 0.9823682	total: 3m 57s	remaining: 7m 24s
# 174:	learn: 0.9823539	total: 3m 58s	remaining: 7m 23s
# 175:	learn: 0.9823897	total: 3m 59s	remaining: 7m 21s
# 176:	learn: 0.9824471	total: 4m 1s	remaining: 7m 20s
# 177:	learn: 0.9824327	total: 4m 2s	remaining: 7m 19s
# 178:	learn: 0.9825618	total: 4m 3s	remaining: 7m 17s
# 179:	learn: 0.9828773	total: 4m 5s	remaining: 7m 15s
# 180:	learn: 0.9829060	total: 4m 6s	remaining: 7m 14s
# 181:	learn: 0.9831068	total: 4m 8s	remaining: 7m 13s
# 182:	learn: 0.9832358	total: 4m 10s	remaining: 7m 13s
# 183:	learn: 0.9832358	total: 4m 11s	remaining: 7m 12s
# 184:	learn: 0.9832143	total: 4m 13s	remaining: 7m 10s
# 185:	learn: 0.9832860	total: 4m 14s	remaining: 7m 9s
# 186:	learn: 0.9832502	total: 4m 15s	remaining: 7m 8s
# 187:	learn: 0.9831068	total: 4m 17s	remaining: 7m 7s
# 188:	learn: 0.9831498	total: 4m 19s	remaining: 7m 6s
# 189:	learn: 0.9830924	total: 4m 19s	remaining: 7m 2s
# 190:	learn: 0.9829849	total: 4m 19s	remaining: 6m 59s
# 191:	learn: 0.9829347	total: 4m 20s	remaining: 6m 58s
# 192:	learn: 0.9830494	total: 4m 22s	remaining: 6m 57s
# 193:	learn: 0.9831426	total: 4m 23s	remaining: 6m 56s
# 194:	learn: 0.9833792	total: 4m 25s	remaining: 6m 55s
# 195:	learn: 0.9834294	total: 4m 26s	remaining: 6m 53s
# 196:	learn: 0.9833936	total: 4m 28s	remaining: 6m 52s
# 197:	learn: 0.9833792	total: 4m 29s	remaining: 6m 50s
# 198:	learn: 0.9834222	total: 4m 30s	remaining: 6m 49s
# 199:	learn: 0.9835011	total: 4m 32s	remaining: 6m 48s
# 200:	learn: 0.9836087	total: 4m 33s	remaining: 6m 47s
# 201:	learn: 0.9834294	total: 4m 33s	remaining: 6m 44s
# 202:	learn: 0.9835872	total: 4m 35s	remaining: 6m 42s
# 203:	learn: 0.9835370	total: 4m 36s	remaining: 6m 41s
# 204:	learn: 0.9835441	total: 4m 37s	remaining: 6m 39s
# 205:	learn: 0.9834509	total: 4m 39s	remaining: 6m 38s
# 206:	learn: 0.9834007	total: 4m 39s	remaining: 6m 35s
# 207:	learn: 0.9833864	total: 4m 41s	remaining: 6m 34s
# 208:	learn: 0.9833290	total: 4m 42s	remaining: 6m 33s
# 209:	learn: 0.9833219	total: 4m 43s	remaining: 6m 32s
# 210:	learn: 0.9834294	total: 4m 45s	remaining: 6m 30s
# 211:	learn: 0.9834007	total: 4m 46s	remaining: 6m 29s
# 212:	learn: 0.9833649	total: 4m 47s	remaining: 6m 28s
# 213:	learn: 0.9834438	total: 4m 49s	remaining: 6m 26s
# 214:	learn: 0.9834796	total: 4m 51s	remaining: 6m 25s
# 215:	learn: 0.9834222	total: 4m 51s	remaining: 6m 22s
# 216:	learn: 0.9833936	total: 4m 52s	remaining: 6m 21s
# 217:	learn: 0.9833864	total: 4m 53s	remaining: 6m 20s
# 218:	learn: 0.9833362	total: 4m 55s	remaining: 6m 19s
# 219:	learn: 0.9832502	total: 4m 56s	remaining: 6m 17s
# 220:	learn: 0.9831641	total: 4m 58s	remaining: 6m 16s
# 221:	learn: 0.9831785	total: 4m 59s	remaining: 6m 15s
# 222:	learn: 0.9831498	total: 5m 1s	remaining: 6m 14s
# 223:	learn: 0.9834007	total: 5m 2s	remaining: 6m 12s
# 224:	learn: 0.9833936	total: 5m 4s	remaining: 6m 11s
# 225:	learn: 0.9833434	total: 5m 5s	remaining: 6m 10s
# 226:	learn: 0.9835872	total: 5m 6s	remaining: 6m 9s
# 227:	learn: 0.9835226	total: 5m 8s	remaining: 6m 8s
# 228:	learn: 0.9835585	total: 5m 10s	remaining: 6m 7s
# 229:	learn: 0.9835011	total: 5m 12s	remaining: 6m 6s
# 230:	learn: 0.9835011	total: 5m 13s	remaining: 6m 5s
# 231:	learn: 0.9834796	total: 5m 15s	remaining: 6m 3s
# 232:	learn: 0.9835155	total: 5m 16s	remaining: 6m 2s
# 233:	learn: 0.9835370	total: 5m 18s	remaining: 6m 1s
# 234:	learn: 0.9835370	total: 5m 19s	remaining: 6m
# 235:	learn: 0.9835370	total: 5m 20s	remaining: 5m 58s
# 236:	learn: 0.9835513	total: 5m 22s	remaining: 5m 57s
# 237:	learn: 0.9836589	total: 5m 23s	remaining: 5m 56s
# 238:	learn: 0.9835943	total: 5m 25s	remaining: 5m 55s
# 239:	learn: 0.9837019	total: 5m 26s	remaining: 5m 53s
# 240:	learn: 0.9837377	total: 5m 27s	remaining: 5m 52s
# 241:	learn: 0.9837234	total: 5m 29s	remaining: 5m 50s
# 242:	learn: 0.9837736	total: 5m 30s	remaining: 5m 49s
# 243:	learn: 0.9837879	total: 5m 30s	remaining: 5m 47s
# 244:	learn: 0.9838811	total: 5m 31s	remaining: 5m 45s
# 245:	learn: 0.9839744	total: 5m 33s	remaining: 5m 44s
# 246:	learn: 0.9839313	total: 5m 34s	remaining: 5m 42s
# 247:	learn: 0.9839600	total: 5m 36s	remaining: 5m 41s
# 248:	learn: 0.9839887	total: 5m 37s	remaining: 5m 40s
# 249:	learn: 0.9839457	total: 5m 38s	remaining: 5m 38s
# 250:	learn: 0.9840532	total: 5m 40s	remaining: 5m 37s
# 251:	learn: 0.9840246	total: 5m 41s	remaining: 5m 36s
# 252:	learn: 0.9840389	total: 5m 42s	remaining: 5m 33s
# 253:	learn: 0.9839887	total: 5m 43s	remaining: 5m 32s
# 254:	learn: 0.9839528	total: 5m 45s	remaining: 5m 32s
# 255:	learn: 0.9840102	total: 5m 46s	remaining: 5m 30s
# 256:	learn: 0.9839528	total: 5m 49s	remaining: 5m 30s
# 257:	learn: 0.9840604	total: 5m 50s	remaining: 5m 28s
# 258:	learn: 0.9841249	total: 5m 52s	remaining: 5m 27s
# 259:	learn: 0.9841321	total: 5m 54s	remaining: 5m 27s
# 260:	learn: 0.9842038	total: 5m 57s	remaining: 5m 27s
# 261:	learn: 0.9841034	total: 5m 59s	remaining: 5m 26s
# 262:	learn: 0.9841249	total: 6m	remaining: 5m 24s
# 263:	learn: 0.9840246	total: 6m 1s	remaining: 5m 23s
# 264:	learn: 0.9840389	total: 6m 3s	remaining: 5m 21s
# 265:	learn: 0.9838955	total: 6m 4s	remaining: 5m 20s
# 266:	learn: 0.9840174	total: 6m 5s	remaining: 5m 19s
# 267:	learn: 0.9839170	total: 6m 6s	remaining: 5m 17s
# 268:	learn: 0.9838740	total: 6m 8s	remaining: 5m 16s
# 269:	learn: 0.9838596	total: 6m 9s	remaining: 5m 14s
# 270:	learn: 0.9838955	total: 6m 10s	remaining: 5m 13s
# 271:	learn: 0.9838453	total: 6m 12s	remaining: 5m 11s
# 272:	learn: 0.9839457	total: 6m 13s	remaining: 5m 10s
# 273:	learn: 0.9838668	total: 6m 15s	remaining: 5m 9s
# 274:	learn: 0.9838883	total: 6m 15s	remaining: 5m 7s
# 275:	learn: 0.9838883	total: 6m 17s	remaining: 5m 6s
# 276:	learn: 0.9838310	total: 6m 18s	remaining: 5m 4s
# 277:	learn: 0.9839170	total: 6m 20s	remaining: 5m 3s
# 278:	learn: 0.9840246	total: 6m 22s	remaining: 5m 2s
# 279:	learn: 0.9840246	total: 6m 22s	remaining: 5m
# 280:	learn: 0.9840819	total: 6m 23s	remaining: 4m 58s
# 281:	learn: 0.9841178	total: 6m 25s	remaining: 4m 58s
# 282:	learn: 0.9841321	total: 6m 27s	remaining: 4m 56s
# 283:	learn: 0.9840819	total: 6m 28s	remaining: 4m 55s
# 284:	learn: 0.9840747	total: 6m 29s	remaining: 4m 53s
# 285:	learn: 0.9840102	total: 6m 31s	remaining: 4m 52s
# 286:	learn: 0.9841751	total: 6m 32s	remaining: 4m 51s
# 287:	learn: 0.9842899	total: 6m 34s	remaining: 4m 50s
# 288:	learn: 0.9843329	total: 6m 35s	remaining: 4m 48s
# 289:	learn: 0.9845050	total: 6m 37s	remaining: 4m 47s
# 290:	learn: 0.9845193	total: 6m 38s	remaining: 4m 46s
# 291:	learn: 0.9845480	total: 6m 40s	remaining: 4m 45s
# 292:	learn: 0.9847703	total: 6m 41s	remaining: 4m 43s
# 293:	learn: 0.9848420	total: 6m 43s	remaining: 4m 42s
# 294:	learn: 0.9847703	total: 6m 44s	remaining: 4m 41s
# 295:	learn: 0.9846842	total: 6m 45s	remaining: 4m 39s
# 296:	learn: 0.9847488	total: 6m 47s	remaining: 4m 38s
# 297:	learn: 0.9847488	total: 6m 48s	remaining: 4m 36s
# 298:	learn: 0.9848420	total: 6m 49s	remaining: 4m 35s
# 299:	learn: 0.9847989	total: 6m 50s	remaining: 4m 33s
# 300:	learn: 0.9849782	total: 6m 51s	remaining: 4m 32s
# 301:	learn: 0.9849424	total: 6m 52s	remaining: 4m 30s
# 302:	learn: 0.9849710	total: 6m 54s	remaining: 4m 29s
# 303:	learn: 0.9849495	total: 6m 55s	remaining: 4m 27s
# 304:	learn: 0.9849065	total: 6m 57s	remaining: 4m 26s
# 305:	learn: 0.9849710	total: 6m 58s	remaining: 4m 25s
# 306:	learn: 0.9850642	total: 6m 59s	remaining: 4m 23s
# 307:	learn: 0.9850642	total: 7m	remaining: 4m 22s
# 308:	learn: 0.9850212	total: 7m 2s	remaining: 4m 21s
# 309:	learn: 0.9850786	total: 7m 3s	remaining: 4m 19s
# 310:	learn: 0.9851288	total: 7m 5s	remaining: 4m 18s
# 311:	learn: 0.9851861	total: 7m 6s	remaining: 4m 16s
# 312:	learn: 0.9852005	total: 7m 7s	remaining: 4m 15s
# 313:	learn: 0.9852148	total: 7m 8s	remaining: 4m 14s
# 314:	learn: 0.9852005	total: 7m 10s	remaining: 4m 12s
# 315:	learn: 0.9852148	total: 7m 11s	remaining: 4m 11s
# 316:	learn: 0.9853152	total: 7m 12s	remaining: 4m 9s
# 317:	learn: 0.9853654	total: 7m 14s	remaining: 4m 8s
# 318:	learn: 0.9852865	total: 7m 15s	remaining: 4m 6s
# 319:	learn: 0.9853080	total: 7m 16s	remaining: 4m 5s
# 320:	learn: 0.9853511	total: 7m 18s	remaining: 4m 4s
# 321:	learn: 0.9853367	total: 7m 19s	remaining: 4m 2s
# 322:	learn: 0.9852937	total: 7m 20s	remaining: 4m 1s
# 323:	learn: 0.9853295	total: 7m 21s	remaining: 3m 59s
# 324:	learn: 0.9853367	total: 7m 23s	remaining: 3m 58s
# 325:	learn: 0.9854013	total: 7m 24s	remaining: 3m 57s
# 326:	learn: 0.9853367	total: 7m 24s	remaining: 3m 55s
# 327:	learn: 0.9853295	total: 7m 26s	remaining: 3m 54s
# 328:	learn: 0.9853224	total: 7m 27s	remaining: 3m 52s
# 329:	learn: 0.9853797	total: 7m 29s	remaining: 3m 51s
# 330:	learn: 0.9854371	total: 7m 30s	remaining: 3m 50s
# 331:	learn: 0.9854371	total: 7m 32s	remaining: 3m 48s
# 332:	learn: 0.9854084	total: 7m 33s	remaining: 3m 47s
# 333:	learn: 0.9853869	total: 7m 35s	remaining: 3m 46s
# 334:	learn: 0.9854228	total: 7m 36s	remaining: 3m 44s
# 335:	learn: 0.9854299	total: 7m 37s	remaining: 3m 43s
# 336:	learn: 0.9854801	total: 7m 38s	remaining: 3m 41s
# 337:	learn: 0.9855160	total: 7m 39s	remaining: 3m 40s
# 338:	learn: 0.9856379	total: 7m 41s	remaining: 3m 39s
# 339:	learn: 0.9857096	total: 7m 42s	remaining: 3m 37s
# 340:	learn: 0.9857311	total: 7m 43s	remaining: 3m 36s
# 341:	learn: 0.9857526	total: 7m 45s	remaining: 3m 34s
# 342:	learn: 0.9858100	total: 7m 46s	remaining: 3m 33s
# 343:	learn: 0.9857813	total: 7m 47s	remaining: 3m 32s
# 344:	learn: 0.9858386	total: 7m 49s	remaining: 3m 30s
# 345:	learn: 0.9858171	total: 7m 50s	remaining: 3m 29s
# 346:	learn: 0.9858602	total: 7m 51s	remaining: 3m 28s
# 347:	learn: 0.9859605	total: 7m 53s	remaining: 3m 26s
# 348:	learn: 0.9859462	total: 7m 54s	remaining: 3m 25s
# 349:	learn: 0.9859175	total: 7m 56s	remaining: 3m 24s
# 350:	learn: 0.9859820	total: 7m 57s	remaining: 3m 22s
# 351:	learn: 0.9860537	total: 7m 58s	remaining: 3m 21s
# 352:	learn: 0.9861111	total: 8m	remaining: 3m 19s
# 353:	learn: 0.9861685	total: 8m 1s	remaining: 3m 18s
# 354:	learn: 0.9861756	total: 8m 3s	remaining: 3m 17s
# 355:	learn: 0.9862473	total: 8m 4s	remaining: 3m 16s
# 356:	learn: 0.9861756	total: 8m 6s	remaining: 3m 14s
# 357:	learn: 0.9864194	total: 8m 7s	remaining: 3m 13s
# 358:	learn: 0.9863908	total: 8m 8s	remaining: 3m 11s
# 359:	learn: 0.9863979	total: 8m 10s	remaining: 3m 10s
# 360:	learn: 0.9864123	total: 8m 11s	remaining: 3m 9s
# 361:	learn: 0.9863908	total: 8m 11s	remaining: 3m 7s
# 362:	learn: 0.9863764	total: 8m 12s	remaining: 3m 5s
# 363:	learn: 0.9864123	total: 8m 13s	remaining: 3m 4s
# 364:	learn: 0.9864625	total: 8m 15s	remaining: 3m 3s
# 365:	learn: 0.9864553	total: 8m 16s	remaining: 3m 1s
# 366:	learn: 0.9865700	total: 8m 17s	remaining: 3m
# 367:	learn: 0.9865915	total: 8m 19s	remaining: 2m 59s
# 368:	learn: 0.9865270	total: 8m 19s	remaining: 2m 57s
# 369:	learn: 0.9865628	total: 8m 20s	remaining: 2m 55s
# 370:	learn: 0.9864983	total: 8m 21s	remaining: 2m 54s
# 371:	learn: 0.9865772	total: 8m 22s	remaining: 2m 53s
# 372:	learn: 0.9866991	total: 8m 24s	remaining: 2m 51s
# 373:	learn: 0.9867636	total: 8m 25s	remaining: 2m 50s
# 374:	learn: 0.9867708	total: 8m 26s	remaining: 2m 48s
# 375:	learn: 0.9867851	total: 8m 28s	remaining: 2m 47s
# 376:	learn: 0.9867995	total: 8m 29s	remaining: 2m 46s
# 377:	learn: 0.9867851	total: 8m 30s	remaining: 2m 44s
# 378:	learn: 0.9867779	total: 8m 32s	remaining: 2m 43s
# 379:	learn: 0.9867995	total: 8m 33s	remaining: 2m 42s
# 380:	learn: 0.9868210	total: 8m 34s	remaining: 2m 40s
# 381:	learn: 0.9868425	total: 8m 35s	remaining: 2m 39s
# 382:	learn: 0.9868855	total: 8m 36s	remaining: 2m 37s
# 383:	learn: 0.9869214	total: 8m 38s	remaining: 2m 36s
# 384:	learn: 0.9869142	total: 8m 39s	remaining: 2m 35s
# 385:	learn: 0.9869572	total: 8m 41s	remaining: 2m 33s
# 386:	learn: 0.9870934	total: 8m 42s	remaining: 2m 32s
# 387:	learn: 0.9870289	total: 8m 43s	remaining: 2m 31s
# 388:	learn: 0.9870361	total: 8m 44s	remaining: 2m 29s
# 389:	learn: 0.9870217	total: 8m 46s	remaining: 2m 28s
# 390:	learn: 0.9870791	total: 8m 47s	remaining: 2m 27s
# 391:	learn: 0.9870289	total: 8m 49s	remaining: 2m 25s
# 392:	learn: 0.9870791	total: 8m 50s	remaining: 2m 24s
# 393:	learn: 0.9870433	total: 8m 51s	remaining: 2m 23s
# 394:	learn: 0.9871221	total: 8m 53s	remaining: 2m 21s
# 395:	learn: 0.9871365	total: 8m 55s	remaining: 2m 20s
# 396:	learn: 0.9871293	total: 8m 57s	remaining: 2m 19s
# 397:	learn: 0.9872153	total: 8m 58s	remaining: 2m 18s
# 398:	learn: 0.9872368	total: 9m	remaining: 2m 16s
# 399:	learn: 0.9872512	total: 9m 1s	remaining: 2m 15s
# 400:	learn: 0.9872655	total: 9m 2s	remaining: 2m 14s
# 401:	learn: 0.9872368	total: 9m 4s	remaining: 2m 12s
# 402:	learn: 0.9872153	total: 9m 5s	remaining: 2m 11s
# 403:	learn: 0.9872942	total: 9m 6s	remaining: 2m 9s
# 404:	learn: 0.9872584	total: 9m 7s	remaining: 2m 8s
# 405:	learn: 0.9872512	total: 9m 9s	remaining: 2m 7s
# 406:	learn: 0.9872655	total: 9m 10s	remaining: 2m 5s
# 407:	learn: 0.9872440	total: 9m 11s	remaining: 2m 4s
# 408:	learn: 0.9872870	total: 9m 13s	remaining: 2m 3s
# 409:	learn: 0.9872870	total: 9m 14s	remaining: 2m 1s
# 410:	learn: 0.9872799	total: 9m 15s	remaining: 2m
# 411:	learn: 0.9872512	total: 9m 17s	remaining: 1m 58s
# 412:	learn: 0.9872655	total: 9m 18s	remaining: 1m 57s
# 413:	learn: 0.9873229	total: 9m 19s	remaining: 1m 56s
# 414:	learn: 0.9872799	total: 9m 20s	remaining: 1m 54s
# 415:	learn: 0.9872870	total: 9m 22s	remaining: 1m 53s
# 416:	learn: 0.9874233	total: 9m 23s	remaining: 1m 52s
# 417:	learn: 0.9873444	total: 9m 24s	remaining: 1m 50s
# 418:	learn: 0.9873946	total: 9m 25s	remaining: 1m 49s
# 419:	learn: 0.9874018	total: 9m 27s	remaining: 1m 48s
# 420:	learn: 0.9873372	total: 9m 28s	remaining: 1m 46s
# 421:	learn: 0.9873229	total: 9m 29s	remaining: 1m 45s
# 422:	learn: 0.9873659	total: 9m 31s	remaining: 1m 43s
# 423:	learn: 0.9873946	total: 9m 32s	remaining: 1m 42s
# 424:	learn: 0.9874304	total: 9m 33s	remaining: 1m 41s
# 425:	learn: 0.9874591	total: 9m 35s	remaining: 1m 39s
# 426:	learn: 0.9874376	total: 9m 36s	remaining: 1m 38s
# 427:	learn: 0.9874735	total: 9m 37s	remaining: 1m 37s
# 428:	learn: 0.9874304	total: 9m 39s	remaining: 1m 35s
# 429:	learn: 0.9874161	total: 9m 40s	remaining: 1m 34s
# 430:	learn: 0.9874950	total: 9m 41s	remaining: 1m 33s
# 431:	learn: 0.9874806	total: 9m 43s	remaining: 1m 31s
# 432:	learn: 0.9875810	total: 9m 44s	remaining: 1m 30s
# 433:	learn: 0.9876599	total: 9m 46s	remaining: 1m 29s
# 434:	learn: 0.9877531	total: 9m 48s	remaining: 1m 27s
# 435:	learn: 0.9877818	total: 9m 49s	remaining: 1m 26s
# 436:	learn: 0.9878033	total: 9m 51s	remaining: 1m 25s
# 437:	learn: 0.9877818	total: 9m 52s	remaining: 1m 23s
# 438:	learn: 0.9879539	total: 9m 53s	remaining: 1m 22s
# 439:	learn: 0.9879826	total: 9m 55s	remaining: 1m 21s
# 440:	learn: 0.9879754	total: 9m 56s	remaining: 1m 19s
# 441:	learn: 0.9879611	total: 9m 58s	remaining: 1m 18s
# 442:	learn: 0.9879682	total: 10m	remaining: 1m 17s
# 443:	learn: 0.9880112	total: 10m 2s	remaining: 1m 16s
# 444:	learn: 0.9879754	total: 10m 5s	remaining: 1m 14s
# 445:	learn: 0.9879539	total: 10m 7s	remaining: 1m 13s
# 446:	learn: 0.9879037	total: 10m 8s	remaining: 1m 12s
# 447:	learn: 0.9879754	total: 10m 9s	remaining: 1m 10s
# 448:	learn: 0.9879395	total: 10m 10s	remaining: 1m 9s
# 449:	learn: 0.9881188	total: 10m 12s	remaining: 1m 8s
# 450:	learn: 0.9881188	total: 10m 14s	remaining: 1m 6s
# 451:	learn: 0.9881188	total: 10m 15s	remaining: 1m 5s
# 452:	learn: 0.9880758	total: 10m 17s	remaining: 1m 4s
# 453:	learn: 0.9880399	total: 10m 18s	remaining: 1m 2s
# 454:	learn: 0.9880328	total: 10m 20s	remaining: 1m 1s
# 455:	learn: 0.9880758	total: 10m 22s	remaining: 1m
# 456:	learn: 0.9881762	total: 10m 24s	remaining: 58.7s
# 457:	learn: 0.9881546	total: 10m 25s	remaining: 57.4s
# 458:	learn: 0.9881833	total: 10m 26s	remaining: 56s
# 459:	learn: 0.9881546	total: 10m 28s	remaining: 54.6s
# 460:	learn: 0.9882765	total: 10m 29s	remaining: 53.3s
# 461:	learn: 0.9882909	total: 10m 31s	remaining: 51.9s
# 462:	learn: 0.9883626	total: 10m 32s	remaining: 50.6s
# 463:	learn: 0.9883339	total: 10m 33s	remaining: 49.2s
# 464:	learn: 0.9883196	total: 10m 35s	remaining: 47.8s
# 465:	learn: 0.9883554	total: 10m 36s	remaining: 46.5s
# 466:	learn: 0.9883482	total: 10m 38s	remaining: 45.1s
# 467:	learn: 0.9883913	total: 10m 39s	remaining: 43.7s
# 468:	learn: 0.9884988	total: 10m 41s	remaining: 42.4s
# 469:	learn: 0.9885562	total: 10m 42s	remaining: 41s
# 470:	learn: 0.9885849	total: 10m 43s	remaining: 39.6s
# 471:	learn: 0.9885777	total: 10m 44s	remaining: 38.3s
# 472:	learn: 0.9885705	total: 10m 46s	remaining: 36.9s
# 473:	learn: 0.9885490	total: 10m 47s	remaining: 35.5s
# 474:	learn: 0.9885203	total: 10m 49s	remaining: 34.2s
# 475:	learn: 0.9885060	total: 10m 50s	remaining: 32.8s
# 476:	learn: 0.9885060	total: 10m 51s	remaining: 31.4s
# 477:	learn: 0.9885203	total: 10m 53s	remaining: 30.1s
# 478:	learn: 0.9885705	total: 10m 54s	remaining: 28.7s
# 479:	learn: 0.9886135	total: 10m 55s	remaining: 27.3s
# 480:	learn: 0.9888000	total: 10m 57s	remaining: 26s
# 481:	learn: 0.9888430	total: 10m 58s	remaining: 24.6s
# 482:	learn: 0.9887570	total: 10m 59s	remaining: 23.2s
# 483:	learn: 0.9887928	total: 11m 1s	remaining: 21.9s
# 484:	learn: 0.9887426	total: 11m 2s	remaining: 20.5s
# 485:	learn: 0.9887211	total: 11m 3s	remaining: 19.1s
# 486:	learn: 0.9887641	total: 11m 5s	remaining: 17.8s
# 487:	learn: 0.9887785	total: 11m 6s	remaining: 16.4s
# 488:	learn: 0.9887713	total: 11m 6s	remaining: 15s
# 489:	learn: 0.9887283	total: 11m 8s	remaining: 13.6s
# 490:	learn: 0.9887139	total: 11m 8s	remaining: 12.3s
# 491:	learn: 0.9887426	total: 11m 9s	remaining: 10.9s
# 492:	learn: 0.9887641	total: 11m 11s	remaining: 9.53s
# 493:	learn: 0.9887139	total: 11m 12s	remaining: 8.17s
# 494:	learn: 0.9887426	total: 11m 13s	remaining: 6.8s
# 495:	learn: 0.9887426	total: 11m 13s	remaining: 5.43s
# 496:	learn: 0.9887426	total: 11m 15s	remaining: 4.08s
# 497:	learn: 0.9887856	total: 11m 16s	remaining: 2.72s
# 498:	learn: 0.9889721	total: 11m 17s	remaining: 1.36s
# 499:	learn: 0.9889434	total: 11m 19s	remaining: 0us
# Train ROC AUC: 0.9889
# Holdout ROC AUC: 0.8461
# CPU times: user 29min 37s, sys: 5min 9s, total: 34min 47s
# Wall time: 11min 33s

# %% [markdown]
# Ну, на холде скор вроде повыше, но попробуем, че б не засабмитить.

# %%
pipe_cat.fit(X, y)

submission = pd.read_csv(submission_file)
submission['y'] = pipe_cat.predict_proba(X_test)[:,1]
submission.to_csv('submission_cat_modified_2.csv', index=False)
# Out:
# 0:	learn: 0.8694904	total: 1.21s	remaining: 10m 2s
# 1:	learn: 0.8961948	total: 2.54s	remaining: 10m 31s
# 2:	learn: 0.8954883	total: 3.8s	remaining: 10m 28s
# 3:	learn: 0.8979452	total: 5.08s	remaining: 10m 30s
# 4:	learn: 0.9009961	total: 6.32s	remaining: 10m 25s
# 5:	learn: 0.9097236	total: 7.5s	remaining: 10m 17s
# 6:	learn: 0.9147956	total: 8.79s	remaining: 10m 19s
# 7:	learn: 0.9233262	total: 10.2s	remaining: 10m 26s
# 8:	learn: 0.9295792	total: 11.6s	remaining: 10m 30s
# 9:	learn: 0.9316793	total: 12.8s	remaining: 10m 25s
# 10:	learn: 0.9321714	total: 14s	remaining: 10m 21s
# 11:	learn: 0.9397653	total: 15.2s	remaining: 10m 19s
# 12:	learn: 0.9393998	total: 16.5s	remaining: 10m 16s
# 13:	learn: 0.9422223	total: 17.8s	remaining: 10m 16s
# 14:	learn: 0.9462468	total: 19.1s	remaining: 10m 18s
# 15:	learn: 0.9483803	total: 20.4s	remaining: 10m 17s
# 16:	learn: 0.9490236	total: 21.7s	remaining: 10m 17s
# 17:	learn: 0.9518759	total: 23.1s	remaining: 10m 18s
# 18:	learn: 0.9519919	total: 24.4s	remaining: 10m 18s
# 19:	learn: 0.9531799	total: 25.7s	remaining: 10m 16s
# 20:	learn: 0.9544699	total: 26.9s	remaining: 10m 14s
# 21:	learn: 0.9551272	total: 28.2s	remaining: 10m 11s
# 22:	learn: 0.9559672	total: 29.4s	remaining: 10m 9s
# 23:	learn: 0.9556579	total: 30.7s	remaining: 10m 9s
# 24:	learn: 0.9543750	total: 32s	remaining: 10m 7s
# 25:	learn: 0.9550235	total: 33.4s	remaining: 10m 9s
# 26:	learn: 0.9552976	total: 34.7s	remaining: 10m 7s
# 27:	learn: 0.9554945	total: 36s	remaining: 10m 6s
# 28:	learn: 0.9562642	total: 37.2s	remaining: 10m 4s
# 29:	learn: 0.9564681	total: 38.6s	remaining: 10m 4s
# 30:	learn: 0.9566649	total: 39.9s	remaining: 10m 3s
# 31:	learn: 0.9570762	total: 41.3s	remaining: 10m 3s
# 32:	learn: 0.9577616	total: 42.9s	remaining: 10m 7s
# 33:	learn: 0.9583275	total: 44.5s	remaining: 10m 10s
# 34:	learn: 0.9580533	total: 46.8s	remaining: 10m 22s
# 35:	learn: 0.9586544	total: 48.2s	remaining: 10m 21s
# 36:	learn: 0.9581728	total: 48.8s	remaining: 10m 10s
# 37:	learn: 0.9587528	total: 51.1s	remaining: 10m 21s
# 38:	learn: 0.9590937	total: 53.4s	remaining: 10m 30s
# 39:	learn: 0.9588969	total: 55.4s	remaining: 10m 36s
# 40:	learn: 0.9607000	total: 56.7s	remaining: 10m 34s
# 41:	learn: 0.9600990	total: 58.2s	remaining: 10m 35s
# 42:	learn: 0.9605840	total: 59.7s	remaining: 10m 34s
# 43:	learn: 0.9602923	total: 1m 1s	remaining: 10m 38s
# 44:	learn: 0.9606016	total: 1m 3s	remaining: 10m 41s
# 45:	learn: 0.9610831	total: 1m 4s	remaining: 10m 39s
# 46:	learn: 0.9606965	total: 1m 6s	remaining: 10m 36s
# 47:	learn: 0.9606508	total: 1m 7s	remaining: 10m 35s
# 48:	learn: 0.9608406	total: 1m 8s	remaining: 10m 34s
# 49:	learn: 0.9607984	total: 1m 10s	remaining: 10m 32s
# 50:	learn: 0.9604856	total: 1m 11s	remaining: 10m 28s
# 51:	learn: 0.9605700	total: 1m 12s	remaining: 10m 26s
# 52:	learn: 0.9611921	total: 1m 14s	remaining: 10m 24s
# 53:	learn: 0.9612835	total: 1m 15s	remaining: 10m 22s
# 54:	learn: 0.9612765	total: 1m 16s	remaining: 10m 20s
# 55:	learn: 0.9618494	total: 1m 17s	remaining: 10m 18s
# 56:	learn: 0.9622712	total: 1m 19s	remaining: 10m 15s
# 57:	learn: 0.9626543	total: 1m 20s	remaining: 10m 13s
# 58:	learn: 0.9625207	total: 1m 21s	remaining: 10m 11s
# 59:	learn: 0.9631148	total: 1m 23s	remaining: 10m 10s
# 60:	learn: 0.9631183	total: 1m 24s	remaining: 10m 8s
# 61:	learn: 0.9640040	total: 1m 25s	remaining: 10m 6s
# 62:	learn: 0.9644574	total: 1m 27s	remaining: 10m 5s
# 63:	learn: 0.9638248	total: 1m 28s	remaining: 10m 3s
# 64:	learn: 0.9639126	total: 1m 29s	remaining: 10m
# 65:	learn: 0.9641060	total: 1m 30s	remaining: 9m 57s
# 66:	learn: 0.9648792	total: 1m 32s	remaining: 9m 55s
# 67:	learn: 0.9648757	total: 1m 33s	remaining: 9m 53s
# 68:	learn: 0.9651007	total: 1m 34s	remaining: 9m 52s
# 69:	learn: 0.9650479	total: 1m 35s	remaining: 9m 49s
# 70:	learn: 0.9654732	total: 1m 37s	remaining: 9m 49s
# 71:	learn: 0.9652905	total: 1m 38s	remaining: 9m 48s
# 72:	learn: 0.9651288	total: 1m 39s	remaining: 9m 42s
# 73:	learn: 0.9650163	total: 1m 40s	remaining: 9m 40s
# 74:	learn: 0.9649530	total: 1m 42s	remaining: 9m 39s
# 75:	learn: 0.9647457	total: 1m 43s	remaining: 9m 37s
# 76:	learn: 0.9653080	total: 1m 44s	remaining: 9m 35s
# 77:	learn: 0.9652659	total: 1m 45s	remaining: 9m 33s
# 78:	learn: 0.9653537	total: 1m 47s	remaining: 9m 31s
# 79:	learn: 0.9657826	total: 1m 48s	remaining: 9m 29s
# 80:	learn: 0.9657931	total: 1m 49s	remaining: 9m 28s
# 81:	learn: 0.9662571	total: 1m 51s	remaining: 9m 26s
# 82:	learn: 0.9660743	total: 1m 52s	remaining: 9m 25s
# 83:	learn: 0.9662430	total: 1m 53s	remaining: 9m 19s
# 84:	learn: 0.9662219	total: 1m 54s	remaining: 9m 19s
# 85:	learn: 0.9662289	total: 1m 55s	remaining: 9m 18s
# 86:	learn: 0.9664187	total: 1m 57s	remaining: 9m 16s
# 87:	learn: 0.9663344	total: 1m 58s	remaining: 9m 14s
# 88:	learn: 0.9662043	total: 1m 59s	remaining: 9m 12s
# 89:	learn: 0.9661200	total: 2m	remaining: 9m 10s
# 90:	learn: 0.9663238	total: 2m 2s	remaining: 9m 9s
# 91:	learn: 0.9668300	total: 2m 3s	remaining: 9m 7s
# 92:	learn: 0.9667175	total: 2m 4s	remaining: 9m 6s
# 93:	learn: 0.9665383	total: 2m 6s	remaining: 9m 5s
# 94:	learn: 0.9667702	total: 2m 8s	remaining: 9m 5s
# 95:	learn: 0.9672483	total: 2m 9s	remaining: 9m 5s
# 96:	learn: 0.9674802	total: 2m 11s	remaining: 9m 5s
# 97:	learn: 0.9676665	total: 2m 12s	remaining: 9m 4s
# 98:	learn: 0.9673783	total: 2m 14s	remaining: 9m 3s
# 99:	learn: 0.9674838	total: 2m 16s	remaining: 9m 5s
# 100:	learn: 0.9673713	total: 2m 18s	remaining: 9m 5s
# 101:	learn: 0.9670303	total: 2m 20s	remaining: 9m 6s
# 102:	learn: 0.9672553	total: 2m 21s	remaining: 9m 7s
# 103:	learn: 0.9671358	total: 2m 23s	remaining: 9m 5s
# 104:	learn: 0.9672975	total: 2m 24s	remaining: 9m 3s
# 105:	learn: 0.9672483	total: 2m 26s	remaining: 9m 2s
# 106:	learn: 0.9672588	total: 2m 27s	remaining: 9m
# 107:	learn: 0.9671428	total: 2m 28s	remaining: 8m 58s
# 108:	learn: 0.9675189	total: 2m 29s	remaining: 8m 57s
# 109:	learn: 0.9673397	total: 2m 31s	remaining: 8m 55s
# 110:	learn: 0.9672869	total: 2m 32s	remaining: 8m 54s
# 111:	learn: 0.9673010	total: 2m 33s	remaining: 8m 53s
# 112:	learn: 0.9672623	total: 2m 35s	remaining: 8m 53s
# 113:	learn: 0.9672131	total: 2m 37s	remaining: 8m 52s
# 114:	learn: 0.9670198	total: 2m 37s	remaining: 8m 48s
# 115:	learn: 0.9671991	total: 2m 39s	remaining: 8m 46s
# 116:	learn: 0.9671604	total: 2m 40s	remaining: 8m 44s
# 117:	learn: 0.9674697	total: 2m 41s	remaining: 8m 43s
# 118:	learn: 0.9671604	total: 2m 43s	remaining: 8m 42s
# 119:	learn: 0.9671147	total: 2m 44s	remaining: 8m 40s
# 120:	learn: 0.9668968	total: 2m 45s	remaining: 8m 37s
# 121:	learn: 0.9669354	total: 2m 45s	remaining: 8m 33s
# 122:	learn: 0.9671323	total: 2m 47s	remaining: 8m 33s
# 123:	learn: 0.9670620	total: 2m 48s	remaining: 8m 32s
# 124:	learn: 0.9670831	total: 2m 50s	remaining: 8m 31s
# 125:	learn: 0.9673256	total: 2m 51s	remaining: 8m 29s
# 126:	learn: 0.9670585	total: 2m 53s	remaining: 8m 28s
# 127:	learn: 0.9672834	total: 2m 54s	remaining: 8m 26s
# 128:	learn: 0.9675857	total: 2m 55s	remaining: 8m 25s
# 129:	learn: 0.9675751	total: 2m 57s	remaining: 8m 23s
# 130:	learn: 0.9675787	total: 2m 58s	remaining: 8m 22s
# 131:	learn: 0.9677368	total: 2m 59s	remaining: 8m 21s
# 132:	learn: 0.9677298	total: 3m 1s	remaining: 8m 20s
# 133:	learn: 0.9678669	total: 3m 2s	remaining: 8m 18s
# 134:	learn: 0.9678985	total: 3m 3s	remaining: 8m 17s
# 135:	learn: 0.9680391	total: 3m 5s	remaining: 8m 15s
# 136:	learn: 0.9681270	total: 3m 6s	remaining: 8m 13s
# 137:	learn: 0.9680989	total: 3m 7s	remaining: 8m 12s
# 138:	learn: 0.9680426	total: 3m 8s	remaining: 8m 10s
# 139:	learn: 0.9680567	total: 3m 10s	remaining: 8m 9s
# 140:	learn: 0.9679758	total: 3m 11s	remaining: 8m 7s
# 141:	learn: 0.9676419	total: 3m 11s	remaining: 8m 2s
# 142:	learn: 0.9675857	total: 3m 12s	remaining: 8m 1s
# 143:	learn: 0.9676911	total: 3m 14s	remaining: 7m 59s
# 144:	learn: 0.9677685	total: 3m 15s	remaining: 7m 58s
# 145:	learn: 0.9675962	total: 3m 16s	remaining: 7m 56s
# 146:	learn: 0.9678177	total: 3m 17s	remaining: 7m 55s
# 147:	learn: 0.9680145	total: 3m 19s	remaining: 7m 54s
# 148:	learn: 0.9680461	total: 3m 21s	remaining: 7m 53s
# 149:	learn: 0.9679477	total: 3m 22s	remaining: 7m 52s
# 150:	learn: 0.9678739	total: 3m 23s	remaining: 7m 50s
# 151:	learn: 0.9678036	total: 3m 25s	remaining: 7m 49s
# 152:	learn: 0.9678071	total: 3m 26s	remaining: 7m 48s
# 153:	learn: 0.9681094	total: 3m 28s	remaining: 7m 47s
# 154:	learn: 0.9680954	total: 3m 29s	remaining: 7m 46s
# 155:	learn: 0.9681305	total: 3m 30s	remaining: 7m 44s
# 156:	learn: 0.9682500	total: 3m 32s	remaining: 7m 43s
# 157:	learn: 0.9682078	total: 3m 33s	remaining: 7m 42s
# 158:	learn: 0.9682606	total: 3m 35s	remaining: 7m 41s
# 159:	learn: 0.9683098	total: 3m 36s	remaining: 7m 40s
# 160:	learn: 0.9684925	total: 3m 37s	remaining: 7m 38s
# 161:	learn: 0.9684925	total: 3m 39s	remaining: 7m 38s
# 162:	learn: 0.9684258	total: 3m 42s	remaining: 7m 39s
# 163:	learn: 0.9685171	total: 3m 43s	remaining: 7m 38s
# 164:	learn: 0.9686296	total: 3m 45s	remaining: 7m 37s
# 165:	learn: 0.9686366	total: 3m 47s	remaining: 7m 37s
# 166:	learn: 0.9684750	total: 3m 48s	remaining: 7m 36s
# 167:	learn: 0.9685242	total: 3m 50s	remaining: 7m 35s
# 168:	learn: 0.9682957	total: 3m 51s	remaining: 7m 33s
# 169:	learn: 0.9686507	total: 3m 53s	remaining: 7m 33s
# 170:	learn: 0.9685663	total: 3m 55s	remaining: 7m 32s
# 171:	learn: 0.9685277	total: 3m 56s	remaining: 7m 30s
# 172:	learn: 0.9684820	total: 3m 57s	remaining: 7m 28s
# 173:	learn: 0.9684047	total: 3m 58s	remaining: 7m 27s
# 174:	learn: 0.9683062	total: 4m	remaining: 7m 26s
# 175:	learn: 0.9684960	total: 4m 1s	remaining: 7m 24s
# 176:	learn: 0.9685558	total: 4m 2s	remaining: 7m 22s
# 177:	learn: 0.9685171	total: 4m 3s	remaining: 7m 21s
# 178:	learn: 0.9684890	total: 4m 5s	remaining: 7m 19s
# 179:	learn: 0.9686402	total: 4m 6s	remaining: 7m 18s
# 180:	learn: 0.9685523	total: 4m 6s	remaining: 7m 14s
# 181:	learn: 0.9685558	total: 4m 7s	remaining: 7m 12s
# 182:	learn: 0.9684785	total: 4m 8s	remaining: 7m 11s
# 183:	learn: 0.9686085	total: 4m 10s	remaining: 7m 9s
# 184:	learn: 0.9686156	total: 4m 11s	remaining: 7m 8s
# 185:	learn: 0.9686612	total: 4m 12s	remaining: 7m 6s
# 186:	learn: 0.9685804	total: 4m 13s	remaining: 7m 4s
# 187:	learn: 0.9686823	total: 4m 15s	remaining: 7m 3s
# 188:	learn: 0.9687245	total: 4m 16s	remaining: 7m 2s
# 189:	learn: 0.9687351	total: 4m 17s	remaining: 7m
# 190:	learn: 0.9686366	total: 4m 19s	remaining: 6m 59s
# 191:	learn: 0.9687034	total: 4m 20s	remaining: 6m 57s
# 192:	learn: 0.9686894	total: 4m 21s	remaining: 6m 56s
# 193:	learn: 0.9687069	total: 4m 23s	remaining: 6m 54s
# 194:	learn: 0.9685488	total: 4m 24s	remaining: 6m 53s
# 195:	learn: 0.9686261	total: 4m 25s	remaining: 6m 51s
# 196:	learn: 0.9686577	total: 4m 26s	remaining: 6m 50s
# 197:	learn: 0.9687597	total: 4m 28s	remaining: 6m 48s
# 198:	learn: 0.9688581	total: 4m 29s	remaining: 6m 47s
# 199:	learn: 0.9687983	total: 4m 30s	remaining: 6m 46s
# 200:	learn: 0.9687175	total: 4m 31s	remaining: 6m 44s
# 201:	learn: 0.9688651	total: 4m 33s	remaining: 6m 43s
# 202:	learn: 0.9688792	total: 4m 34s	remaining: 6m 41s
# 203:	learn: 0.9689249	total: 4m 35s	remaining: 6m 40s
# 204:	learn: 0.9689495	total: 4m 37s	remaining: 6m 38s
# 205:	learn: 0.9688616	total: 4m 38s	remaining: 6m 37s
# 206:	learn: 0.9688967	total: 4m 39s	remaining: 6m 36s
# 207:	learn: 0.9687667	total: 4m 41s	remaining: 6m 35s
# 208:	learn: 0.9689952	total: 4m 42s	remaining: 6m 33s
# 209:	learn: 0.9688932	total: 4m 42s	remaining: 6m 30s
# 210:	learn: 0.9687843	total: 4m 44s	remaining: 6m 29s
# 211:	learn: 0.9689495	total: 4m 45s	remaining: 6m 28s
# 212:	learn: 0.9689495	total: 4m 47s	remaining: 6m 27s
# 213:	learn: 0.9690268	total: 4m 52s	remaining: 6m 30s
# 214:	learn: 0.9690127	total: 4m 54s	remaining: 6m 30s
# 215:	learn: 0.9690373	total: 4m 55s	remaining: 6m 28s
# 216:	learn: 0.9691147	total: 4m 57s	remaining: 6m 27s
# 217:	learn: 0.9691920	total: 4m 59s	remaining: 6m 26s
# 218:	learn: 0.9692342	total: 5m	remaining: 6m 25s
# 219:	learn: 0.9692553	total: 5m 2s	remaining: 6m 24s
# 220:	learn: 0.9694029	total: 5m 3s	remaining: 6m 23s
# 221:	learn: 0.9693326	total: 5m 5s	remaining: 6m 22s
# 222:	learn: 0.9696524	total: 5m 6s	remaining: 6m 20s
# 223:	learn: 0.9695505	total: 5m 7s	remaining: 6m 19s
# 224:	learn: 0.9695329	total: 5m 9s	remaining: 6m 18s
# 225:	learn: 0.9697614	total: 5m 11s	remaining: 6m 17s
# 226:	learn: 0.9696981	total: 5m 12s	remaining: 6m 15s
# 227:	learn: 0.9697684	total: 5m 14s	remaining: 6m 14s
# 228:	learn: 0.9697438	total: 5m 15s	remaining: 6m 13s
# 229:	learn: 0.9699161	total: 5m 17s	remaining: 6m 12s
# 230:	learn: 0.9698950	total: 5m 18s	remaining: 6m 11s
# 231:	learn: 0.9697895	total: 5m 20s	remaining: 6m 9s
# 232:	learn: 0.9698247	total: 5m 21s	remaining: 6m 8s
# 233:	learn: 0.9698352	total: 5m 22s	remaining: 6m 7s
# 234:	learn: 0.9697790	total: 5m 24s	remaining: 6m 5s
# 235:	learn: 0.9697227	total: 5m 26s	remaining: 6m 5s
# 236:	learn: 0.9698176	total: 5m 28s	remaining: 6m 4s
# 237:	learn: 0.9697438	total: 5m 29s	remaining: 6m 2s
# 238:	learn: 0.9698282	total: 5m 30s	remaining: 6m 1s
# 239:	learn: 0.9699196	total: 5m 32s	remaining: 5m 59s
# 240:	learn: 0.9699336	total: 5m 34s	remaining: 5m 59s
# 241:	learn: 0.9698528	total: 5m 36s	remaining: 5m 58s
# 242:	learn: 0.9698563	total: 5m 37s	remaining: 5m 56s
# 243:	learn: 0.9697720	total: 5m 38s	remaining: 5m 55s
# 244:	learn: 0.9697157	total: 5m 39s	remaining: 5m 53s
# 245:	learn: 0.9697087	total: 5m 41s	remaining: 5m 52s
# 246:	learn: 0.9696349	total: 5m 42s	remaining: 5m 51s
# 247:	learn: 0.9698176	total: 5m 44s	remaining: 5m 49s
# 248:	learn: 0.9699090	total: 5m 45s	remaining: 5m 48s
# 249:	learn: 0.9698774	total: 5m 46s	remaining: 5m 46s
# 250:	learn: 0.9699407	total: 5m 48s	remaining: 5m 45s
# 251:	learn: 0.9700602	total: 5m 49s	remaining: 5m 43s
# 252:	learn: 0.9702183	total: 5m 50s	remaining: 5m 42s
# 253:	learn: 0.9703168	total: 5m 52s	remaining: 5m 41s
# 254:	learn: 0.9702711	total: 5m 53s	remaining: 5m 39s
# 255:	learn: 0.9703379	total: 5m 54s	remaining: 5m 38s
# 256:	learn: 0.9703625	total: 5m 55s	remaining: 5m 36s
# 257:	learn: 0.9704503	total: 5m 56s	remaining: 5m 34s
# 258:	learn: 0.9704152	total: 5m 57s	remaining: 5m 33s
# 259:	learn: 0.9705523	total: 5m 59s	remaining: 5m 31s
# 260:	learn: 0.9706050	total: 6m	remaining: 5m 30s
# 261:	learn: 0.9707175	total: 6m 1s	remaining: 5m 28s
# 262:	learn: 0.9707069	total: 6m 2s	remaining: 5m 27s
# 263:	learn: 0.9707175	total: 6m 4s	remaining: 5m 25s
# 264:	learn: 0.9706788	total: 6m 6s	remaining: 5m 25s
# 265:	learn: 0.9707561	total: 6m 8s	remaining: 5m 24s
# 266:	learn: 0.9708827	total: 6m 10s	remaining: 5m 22s
# 267:	learn: 0.9707913	total: 6m 12s	remaining: 5m 22s
# 268:	learn: 0.9707139	total: 6m 14s	remaining: 5m 21s
# 269:	learn: 0.9711287	total: 6m 16s	remaining: 5m 20s
# 270:	learn: 0.9711252	total: 6m 17s	remaining: 5m 19s
# 271:	learn: 0.9712306	total: 6m 19s	remaining: 5m 18s
# 272:	learn: 0.9711744	total: 6m 21s	remaining: 5m 17s
# 273:	learn: 0.9711814	total: 6m 22s	remaining: 5m 15s
# 274:	learn: 0.9710971	total: 6m 23s	remaining: 5m 14s
# 275:	learn: 0.9712588	total: 6m 25s	remaining: 5m 12s
# 276:	learn: 0.9712201	total: 6m 27s	remaining: 5m 11s
# 277:	learn: 0.9712693	total: 6m 28s	remaining: 5m 10s
# 278:	learn: 0.9713220	total: 6m 30s	remaining: 5m 8s
# 279:	learn: 0.9712131	total: 6m 31s	remaining: 5m 7s
# 280:	learn: 0.9713115	total: 6m 32s	remaining: 5m 5s
# 281:	learn: 0.9713783	total: 6m 33s	remaining: 5m 4s
# 282:	learn: 0.9714872	total: 6m 35s	remaining: 5m 2s
# 283:	learn: 0.9714556	total: 6m 36s	remaining: 5m 1s
# 284:	learn: 0.9715153	total: 6m 37s	remaining: 4m 59s
# 285:	learn: 0.9714942	total: 6m 38s	remaining: 4m 58s
# 286:	learn: 0.9715224	total: 6m 40s	remaining: 4m 56s
# 287:	learn: 0.9715927	total: 6m 41s	remaining: 4m 55s
# 288:	learn: 0.9716665	total: 6m 42s	remaining: 4m 53s
# 289:	learn: 0.9716067	total: 6m 44s	remaining: 4m 53s
# 290:	learn: 0.9716313	total: 6m 46s	remaining: 4m 51s
# 291:	learn: 0.9716735	total: 6m 47s	remaining: 4m 50s
# 292:	learn: 0.9717579	total: 6m 49s	remaining: 4m 49s
# 293:	learn: 0.9717614	total: 6m 51s	remaining: 4m 48s
# 294:	learn: 0.9718598	total: 6m 53s	remaining: 4m 47s
# 295:	learn: 0.9719301	total: 6m 55s	remaining: 4m 46s
# 296:	learn: 0.9719125	total: 6m 57s	remaining: 4m 45s
# 297:	learn: 0.9719160	total: 6m 59s	remaining: 4m 44s
# 298:	learn: 0.9719266	total: 7m 1s	remaining: 4m 43s
# 299:	learn: 0.9718914	total: 7m 2s	remaining: 4m 41s
# 300:	learn: 0.9718914	total: 7m 3s	remaining: 4m 40s
# 301:	learn: 0.9721340	total: 7m 5s	remaining: 4m 38s
# 302:	learn: 0.9720531	total: 7m 6s	remaining: 4m 37s
# 303:	learn: 0.9719688	total: 7m 8s	remaining: 4m 36s
# 304:	learn: 0.9720391	total: 7m 10s	remaining: 4m 35s
# 305:	learn: 0.9723378	total: 7m 12s	remaining: 4m 34s
# 306:	learn: 0.9723800	total: 7m 15s	remaining: 4m 33s
# 307:	learn: 0.9723835	total: 7m 18s	remaining: 4m 33s
# 308:	learn: 0.9724187	total: 7m 22s	remaining: 4m 33s
# 309:	learn: 0.9723870	total: 7m 25s	remaining: 4m 33s
# 310:	learn: 0.9723554	total: 7m 27s	remaining: 4m 32s
# 311:	learn: 0.9723202	total: 7m 29s	remaining: 4m 30s
# 312:	learn: 0.9722921	total: 7m 30s	remaining: 4m 29s
# 313:	learn: 0.9724081	total: 7m 32s	remaining: 4m 28s
# 314:	learn: 0.9724608	total: 7m 34s	remaining: 4m 27s
# 315:	learn: 0.9726506	total: 7m 36s	remaining: 4m 25s
# 316:	learn: 0.9726928	total: 7m 37s	remaining: 4m 24s
# 317:	learn: 0.9727385	total: 7m 38s	remaining: 4m 22s
# 318:	learn: 0.9727631	total: 7m 40s	remaining: 4m 21s
# 319:	learn: 0.9727631	total: 7m 41s	remaining: 4m 19s
# 320:	learn: 0.9727702	total: 7m 43s	remaining: 4m 18s
# 321:	learn: 0.9727877	total: 7m 44s	remaining: 4m 17s
# 322:	learn: 0.9728334	total: 7m 46s	remaining: 4m 15s
# 323:	learn: 0.9727948	total: 7m 46s	remaining: 4m 13s
# 324:	learn: 0.9728686	total: 7m 47s	remaining: 4m 11s
# 325:	learn: 0.9728299	total: 7m 49s	remaining: 4m 10s
# 326:	learn: 0.9729283	total: 7m 50s	remaining: 4m 8s
# 327:	learn: 0.9729670	total: 7m 52s	remaining: 4m 7s
# 328:	learn: 0.9730549	total: 7m 53s	remaining: 4m 6s
# 329:	learn: 0.9730162	total: 7m 54s	remaining: 4m 4s
# 330:	learn: 0.9730549	total: 7m 56s	remaining: 4m 3s
# 331:	learn: 0.9730162	total: 7m 57s	remaining: 4m 1s
# 332:	learn: 0.9731111	total: 7m 58s	remaining: 4m
# 333:	learn: 0.9730338	total: 8m	remaining: 3m 58s
# 334:	learn: 0.9730373	total: 8m 1s	remaining: 3m 57s
# 335:	learn: 0.9730549	total: 8m 2s	remaining: 3m 55s
# 336:	learn: 0.9730900	total: 8m 4s	remaining: 3m 54s
# 337:	learn: 0.9731041	total: 8m 5s	remaining: 3m 52s
# 338:	learn: 0.9731146	total: 8m 7s	remaining: 3m 51s
# 339:	learn: 0.9731568	total: 8m 8s	remaining: 3m 49s
# 340:	learn: 0.9732271	total: 8m 9s	remaining: 3m 48s
# 341:	learn: 0.9732974	total: 8m 10s	remaining: 3m 46s
# 342:	learn: 0.9732517	total: 8m 12s	remaining: 3m 45s
# 343:	learn: 0.9731709	total: 8m 13s	remaining: 3m 43s
# 344:	learn: 0.9731146	total: 8m 14s	remaining: 3m 42s
# 345:	learn: 0.9731744	total: 8m 16s	remaining: 3m 40s
# 346:	learn: 0.9732798	total: 8m 17s	remaining: 3m 39s
# 347:	learn: 0.9733431	total: 8m 18s	remaining: 3m 37s
# 348:	learn: 0.9732939	total: 8m 20s	remaining: 3m 36s
# 349:	learn: 0.9733431	total: 8m 21s	remaining: 3m 34s
# 350:	learn: 0.9733009	total: 8m 22s	remaining: 3m 33s
# 351:	learn: 0.9732622	total: 8m 24s	remaining: 3m 31s
# 352:	learn: 0.9733396	total: 8m 25s	remaining: 3m 30s
# 353:	learn: 0.9734696	total: 8m 26s	remaining: 3m 29s
# 354:	learn: 0.9734766	total: 8m 28s	remaining: 3m 27s
# 355:	learn: 0.9734485	total: 8m 29s	remaining: 3m 26s
# 356:	learn: 0.9734977	total: 8m 31s	remaining: 3m 24s
# 357:	learn: 0.9734907	total: 8m 32s	remaining: 3m 23s
# 358:	learn: 0.9734907	total: 8m 34s	remaining: 3m 21s
# 359:	learn: 0.9735575	total: 8m 35s	remaining: 3m 20s
# 360:	learn: 0.9735786	total: 8m 36s	remaining: 3m 18s
# 361:	learn: 0.9737227	total: 8m 37s	remaining: 3m 17s
# 362:	learn: 0.9737403	total: 8m 39s	remaining: 3m 16s
# 363:	learn: 0.9737016	total: 8m 40s	remaining: 3m 14s
# 364:	learn: 0.9737367	total: 8m 42s	remaining: 3m 13s
# 365:	learn: 0.9738070	total: 8m 43s	remaining: 3m 11s
# 366:	learn: 0.9739230	total: 8m 44s	remaining: 3m 10s
# 367:	learn: 0.9739547	total: 8m 46s	remaining: 3m 8s
# 368:	learn: 0.9740320	total: 8m 47s	remaining: 3m 7s
# 369:	learn: 0.9739863	total: 8m 49s	remaining: 3m 5s
# 370:	learn: 0.9740355	total: 8m 50s	remaining: 3m 4s
# 371:	learn: 0.9741831	total: 8m 51s	remaining: 3m 2s
# 372:	learn: 0.9742148	total: 8m 52s	remaining: 3m 1s
# 373:	learn: 0.9741831	total: 8m 53s	remaining: 2m 59s
# 374:	learn: 0.9742007	total: 8m 55s	remaining: 2m 58s
# 375:	learn: 0.9743413	total: 8m 57s	remaining: 2m 57s
# 376:	learn: 0.9744292	total: 8m 59s	remaining: 2m 56s
# 377:	learn: 0.9744995	total: 9m 1s	remaining: 2m 54s
# 378:	learn: 0.9745065	total: 9m 2s	remaining: 2m 53s
# 379:	learn: 0.9744468	total: 9m 4s	remaining: 2m 51s
# 380:	learn: 0.9744327	total: 9m 5s	remaining: 2m 50s
# 381:	learn: 0.9744854	total: 9m 8s	remaining: 2m 49s
# 382:	learn: 0.9745030	total: 9m 9s	remaining: 2m 47s
# 383:	learn: 0.9744960	total: 9m 10s	remaining: 2m 46s
# 384:	learn: 0.9746014	total: 9m 12s	remaining: 2m 44s
# 385:	learn: 0.9746893	total: 9m 13s	remaining: 2m 43s
# 386:	learn: 0.9748791	total: 9m 15s	remaining: 2m 42s
# 387:	learn: 0.9748721	total: 9m 16s	remaining: 2m 40s
# 388:	learn: 0.9749459	total: 9m 19s	remaining: 2m 39s
# 389:	learn: 0.9750302	total: 9m 22s	remaining: 2m 38s
# 390:	learn: 0.9750091	total: 9m 24s	remaining: 2m 37s
# 391:	learn: 0.9750513	total: 9m 26s	remaining: 2m 35s
# 392:	learn: 0.9750478	total: 9m 27s	remaining: 2m 34s
# 393:	learn: 0.9750197	total: 9m 27s	remaining: 2m 32s
# 394:	learn: 0.9750548	total: 9m 29s	remaining: 2m 31s
# 395:	learn: 0.9750830	total: 9m 30s	remaining: 2m 29s
# 396:	learn: 0.9752200	total: 9m 31s	remaining: 2m 28s
# 397:	learn: 0.9753536	total: 9m 33s	remaining: 2m 26s
# 398:	learn: 0.9754063	total: 9m 34s	remaining: 2m 25s
# 399:	learn: 0.9753887	total: 9m 35s	remaining: 2m 23s
# 400:	learn: 0.9754626	total: 9m 37s	remaining: 2m 22s
# 401:	learn: 0.9754766	total: 9m 38s	remaining: 2m 21s
# 402:	learn: 0.9754801	total: 9m 39s	remaining: 2m 19s
# 403:	learn: 0.9755118	total: 9m 41s	remaining: 2m 18s
# 404:	learn: 0.9755856	total: 9m 42s	remaining: 2m 16s
# 405:	learn: 0.9756032	total: 9m 43s	remaining: 2m 15s
# 406:	learn: 0.9756418	total: 9m 44s	remaining: 2m 13s
# 407:	learn: 0.9756910	total: 9m 45s	remaining: 2m 12s
# 408:	learn: 0.9756242	total: 9m 47s	remaining: 2m 10s
# 409:	learn: 0.9757156	total: 9m 48s	remaining: 2m 9s
# 410:	learn: 0.9757262	total: 9m 50s	remaining: 2m 7s
# 411:	learn: 0.9758281	total: 9m 51s	remaining: 2m 6s
# 412:	learn: 0.9759898	total: 9m 53s	remaining: 2m 4s
# 413:	learn: 0.9759582	total: 9m 54s	remaining: 2m 3s
# 414:	learn: 0.9759757	total: 9m 55s	remaining: 2m 2s
# 415:	learn: 0.9759757	total: 9m 57s	remaining: 2m
# 416:	learn: 0.9759722	total: 9m 58s	remaining: 1m 59s
# 417:	learn: 0.9759722	total: 9m 59s	remaining: 1m 57s
# 418:	learn: 0.9759617	total: 10m 1s	remaining: 1m 56s
# 419:	learn: 0.9759687	total: 10m 2s	remaining: 1m 54s
# 420:	learn: 0.9760320	total: 10m 3s	remaining: 1m 53s
# 421:	learn: 0.9760706	total: 10m 5s	remaining: 1m 51s
# 422:	learn: 0.9761901	total: 10m 6s	remaining: 1m 50s
# 423:	learn: 0.9761374	total: 10m 8s	remaining: 1m 48s
# 424:	learn: 0.9761937	total: 10m 9s	remaining: 1m 47s
# 425:	learn: 0.9762112	total: 10m 11s	remaining: 1m 46s
# 426:	learn: 0.9762956	total: 10m 12s	remaining: 1m 44s
# 427:	learn: 0.9762921	total: 10m 13s	remaining: 1m 43s
# 428:	learn: 0.9762815	total: 10m 15s	remaining: 1m 41s
# 429:	learn: 0.9763940	total: 10m 17s	remaining: 1m 40s
# 430:	learn: 0.9764221	total: 10m 18s	remaining: 1m 39s
# 431:	learn: 0.9764432	total: 10m 19s	remaining: 1m 37s
# 432:	learn: 0.9764819	total: 10m 21s	remaining: 1m 36s
# 433:	learn: 0.9765873	total: 10m 22s	remaining: 1m 34s
# 434:	learn: 0.9766471	total: 10m 23s	remaining: 1m 33s
# 435:	learn: 0.9766260	total: 10m 25s	remaining: 1m 31s
# 436:	learn: 0.9766084	total: 10m 26s	remaining: 1m 30s
# 437:	learn: 0.9766752	total: 10m 27s	remaining: 1m 28s
# 438:	learn: 0.9767033	total: 10m 29s	remaining: 1m 27s
# 439:	learn: 0.9766611	total: 10m 29s	remaining: 1m 25s
# 440:	learn: 0.9766471	total: 10m 30s	remaining: 1m 24s
# 441:	learn: 0.9766330	total: 10m 31s	remaining: 1m 22s
# 442:	learn: 0.9766682	total: 10m 32s	remaining: 1m 21s
# 443:	learn: 0.9767560	total: 10m 34s	remaining: 1m 20s
# 444:	learn: 0.9767385	total: 10m 35s	remaining: 1m 18s
# 445:	learn: 0.9767877	total: 10m 36s	remaining: 1m 17s
# 446:	learn: 0.9767244	total: 10m 38s	remaining: 1m 15s
# 447:	learn: 0.9766787	total: 10m 38s	remaining: 1m 14s
# 448:	learn: 0.9766541	total: 10m 39s	remaining: 1m 12s
# 449:	learn: 0.9766119	total: 10m 40s	remaining: 1m 11s
# 450:	learn: 0.9766154	total: 10m 42s	remaining: 1m 9s
# 451:	learn: 0.9766154	total: 10m 43s	remaining: 1m 8s
# 452:	learn: 0.9766647	total: 10m 43s	remaining: 1m 6s
# 453:	learn: 0.9767455	total: 10m 45s	remaining: 1m 5s
# 454:	learn: 0.9767806	total: 10m 46s	remaining: 1m 3s
# 455:	learn: 0.9767701	total: 10m 47s	remaining: 1m 2s
# 456:	learn: 0.9767877	total: 10m 48s	remaining: 1m 1s
# 457:	learn: 0.9767666	total: 10m 50s	remaining: 59.6s
# 458:	learn: 0.9768404	total: 10m 51s	remaining: 58.2s
# 459:	learn: 0.9768826	total: 10m 52s	remaining: 56.8s
# 460:	learn: 0.9769775	total: 10m 54s	remaining: 55.3s
# 461:	learn: 0.9770021	total: 10m 55s	remaining: 53.9s
# 462:	learn: 0.9770021	total: 10m 56s	remaining: 52.5s
# 463:	learn: 0.9770056	total: 10m 58s	remaining: 51.1s
# 464:	learn: 0.9770302	total: 10m 59s	remaining: 49.7s
# 465:	learn: 0.9770267	total: 11m 1s	remaining: 48.3s
# 466:	learn: 0.9770443	total: 11m 2s	remaining: 46.8s
# 467:	learn: 0.9770056	total: 11m 4s	remaining: 45.4s
# 468:	learn: 0.9770126	total: 11m 5s	remaining: 44s
# 469:	learn: 0.9770759	total: 11m 7s	remaining: 42.6s
# 470:	learn: 0.9771286	total: 11m 8s	remaining: 41.2s
# 471:	learn: 0.9771849	total: 11m 9s	remaining: 39.7s
# 472:	learn: 0.9772341	total: 11m 10s	remaining: 38.3s
# 473:	learn: 0.9772587	total: 11m 12s	remaining: 36.9s
# 474:	learn: 0.9772552	total: 11m 13s	remaining: 35.5s
# 475:	learn: 0.9772868	total: 11m 15s	remaining: 34s
# 476:	learn: 0.9773008	total: 11m 16s	remaining: 32.6s
# 477:	learn: 0.9773852	total: 11m 17s	remaining: 31.2s
# 478:	learn: 0.9773957	total: 11m 18s	remaining: 29.8s
# 479:	learn: 0.9773782	total: 11m 20s	remaining: 28.3s
# 480:	learn: 0.9772938	total: 11m 21s	remaining: 26.9s
# 481:	learn: 0.9773360	total: 11m 22s	remaining: 25.5s
# 482:	learn: 0.9773571	total: 11m 22s	remaining: 24s
# 483:	learn: 0.9773290	total: 11m 24s	remaining: 22.6s
# 484:	learn: 0.9773114	total: 11m 25s	remaining: 21.2s
# 485:	learn: 0.9773852	total: 11m 26s	remaining: 19.8s
# 486:	learn: 0.9774660	total: 11m 28s	remaining: 18.4s
# 487:	learn: 0.9774731	total: 11m 29s	remaining: 17s
# 488:	learn: 0.9776383	total: 11m 30s	remaining: 15.5s
# 489:	learn: 0.9776805	total: 11m 32s	remaining: 14.1s
# 490:	learn: 0.9777156	total: 11m 33s	remaining: 12.7s
# 491:	learn: 0.9777543	total: 11m 34s	remaining: 11.3s
# 492:	learn: 0.9777859	total: 11m 35s	remaining: 9.88s
# 493:	learn: 0.9778175	total: 11m 37s	remaining: 8.47s
# 494:	learn: 0.9778738	total: 11m 38s	remaining: 7.06s
# 495:	learn: 0.9779089	total: 11m 40s	remaining: 5.64s
# 496:	learn: 0.9779476	total: 11m 41s	remaining: 4.23s
# 497:	learn: 0.9779511	total: 11m 42s	remaining: 2.82s
# 498:	learn: 0.9779546	total: 11m 44s	remaining: 1.41s
# 499:	learn: 0.9779476	total: 11m 45s	remaining: 0us

# %%
#0.89165
# !kaggle competitions submit -c skill-task -f submission_cat_modified_2.csv -m "Глубина 12"
# Out:
# 100%|██████████████████████████████████████| 5.89k/5.89k [00:00<00:00, 39.1kB/s]
# Successfully submitted to Skill task

# %%
# %%time
''' Let's finally play with Catboost '''

from sklearn.feature_selection import SelectKBest, f_classif
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score

CORR_THRESHOLD = 0.94
CAT_THRESHOLD = 5 # <- and less unique values make feature categorical
#OUT_FRACTION = 0.05 # <- percent of outliers
#K = 400
L2_LEAF_REG = 0.5 # <- regularization coefficient for CatBoost
DEPTH = 12 # <- max tree depth for Catboost, can't be >10, or kernel will just die

cat = CatBoostClassifier(learning_rate=0.001, 
                         iterations=400,
                         loss_function='CrossEntropy',
                         l2_leaf_reg=L2_LEAF_REG,
                         depth=DEPTH,
                         custom_metric='AUC:hints=skip_train~false', #CPU-only
                         eval_metric='AUC:hints=skip_train~false', #CPU-only
                         random_state=17,
                         rsm=0.1, #CPU-only
                         bootstrap_type='Bernoulli',
                         subsample=0.9,
                         #task_type='GPU',
                         verbose=1)
pipe_cat = Pipeline([('pre_proc', FunctionTransformer(pre_proc, validate=False)),
                      ('drop_zero_var', Drop_zero_var()),
                      ('drop_corr', Drop_corr(threshold=CORR_THRESHOLD)),
                      ('lootme', LOOTME_df(threshold=CAT_THRESHOLD)),
                      ('transform', Find_Trans(threshold=CAT_THRESHOLD)),
                      #('feat_sel', SelectKBest(f_classif, K)),
                      ('cat', cat)])

pipe_cat.fit(X_train, y_train)

#scores = cross_val_score(pipe_cat, X_train, y_train, cv=skf, scoring='roc_auc')

print('Train ROC AUC: %.4f' % roc_auc_score(y_train, pipe_cat.predict_proba(X_train)[:,1]))
#print('Cross-validation ROC AUC: mean %.4f, std %.4f' % (scores.mean(), scores.std()))
print('Holdout ROC AUC: %.4f' % roc_auc_score(y_hold, pipe_cat.predict_proba(X_hold)[:,1]))
# Out:
# 0:	learn: 0.8372878	total: 1.3s	remaining: 8m 38s
# 1:	learn: 0.9261853	total: 2.9s	remaining: 9m 37s
# 2:	learn: 0.9283148	total: 4.26s	remaining: 9m 23s
# 3:	learn: 0.9532711	total: 5.71s	remaining: 9m 25s
# 4:	learn: 0.9618611	total: 7.15s	remaining: 9m 25s
# 5:	learn: 0.9637684	total: 8.6s	remaining: 9m 24s
# 6:	learn: 0.9620117	total: 9.87s	remaining: 9m 14s
# 7:	learn: 0.9637326	total: 11.3s	remaining: 9m 12s
# 8:	learn: 0.9659446	total: 12.6s	remaining: 9m 8s
# 9:	learn: 0.9658550	total: 14s	remaining: 9m 4s
# 10:	learn: 0.9685940	total: 15.3s	remaining: 9m 1s
# 11:	learn: 0.9690529	total: 16.7s	remaining: 9m
# 12:	learn: 0.9684076	total: 18.1s	remaining: 8m 58s
# 13:	learn: 0.9671456	total: 19.6s	remaining: 9m
# 14:	learn: 0.9680563	total: 20.8s	remaining: 8m 54s
# 15:	learn: 0.9684506	total: 22.1s	remaining: 8m 51s
# 16:	learn: 0.9671385	total: 22.2s	remaining: 8m 20s
# 17:	learn: 0.9692465	total: 23.8s	remaining: 8m 24s
# 18:	learn: 0.9687446	total: 25.4s	remaining: 8m 28s
# 19:	learn: 0.9683933	total: 26.6s	remaining: 8m 25s
# 20:	learn: 0.9698919	total: 28s	remaining: 8m 24s
# 21:	learn: 0.9708742	total: 29.4s	remaining: 8m 25s
# 22:	learn: 0.9717848	total: 30.7s	remaining: 8m 23s
# 23:	learn: 0.9717848	total: 32.3s	remaining: 8m 25s
# 24:	learn: 0.9714765	total: 34s	remaining: 8m 29s
# 25:	learn: 0.9742299	total: 35.8s	remaining: 8m 35s
# 26:	learn: 0.9757428	total: 38.2s	remaining: 8m 47s
# 27:	learn: 0.9747677	total: 39.9s	remaining: 8m 50s
# 28:	learn: 0.9760440	total: 41.4s	remaining: 8m 49s
# 29:	learn: 0.9762806	total: 42.8s	remaining: 8m 48s
# 30:	learn: 0.9777577	total: 44.2s	remaining: 8m 45s
# 31:	learn: 0.9774996	total: 45.4s	remaining: 8m 42s
# 32:	learn: 0.9768901	total: 45.9s	remaining: 8m 30s
# 33:	learn: 0.9776573	total: 47.3s	remaining: 8m 28s
# 34:	learn: 0.9770263	total: 48.6s	remaining: 8m 27s
# 35:	learn: 0.9764670	total: 49.9s	remaining: 8m 24s
# 36:	learn: 0.9759508	total: 51.2s	remaining: 8m 22s
# 37:	learn: 0.9762304	total: 52.4s	remaining: 8m 19s
# 38:	learn: 0.9758432	total: 53.9s	remaining: 8m 19s
# 39:	learn: 0.9764814	total: 55.4s	remaining: 8m 18s
# 40:	learn: 0.9768542	total: 56.8s	remaining: 8m 17s
# 41:	learn: 0.9762950	total: 58.2s	remaining: 8m 15s
# 42:	learn: 0.9766606	total: 59.5s	remaining: 8m 14s
# 43:	learn: 0.9762806	total: 1m 1s	remaining: 8m 13s
# 44:	learn: 0.9771626	total: 1m 2s	remaining: 8m 12s
# 45:	learn: 0.9773490	total: 1m 3s	remaining: 8m 10s
# 46:	learn: 0.9769044	total: 1m 5s	remaining: 8m 8s
# 47:	learn: 0.9767467	total: 1m 6s	remaining: 8m 7s
# 48:	learn: 0.9768686	total: 1m 7s	remaining: 8m 5s
# 49:	learn: 0.9769044	total: 1m 9s	remaining: 8m 3s
# 50:	learn: 0.9766606	total: 1m 10s	remaining: 8m 1s
# 51:	learn: 0.9775426	total: 1m 11s	remaining: 8m
# 52:	learn: 0.9773705	total: 1m 13s	remaining: 8m 2s
# 53:	learn: 0.9769259	total: 1m 15s	remaining: 8m 1s
# 54:	learn: 0.9773777	total: 1m 16s	remaining: 8m
# 55:	learn: 0.9770263	total: 1m 17s	remaining: 7m 59s
# 56:	learn: 0.9765889	total: 1m 19s	remaining: 7m 57s
# 57:	learn: 0.9776501	total: 1m 20s	remaining: 7m 56s
# 58:	learn: 0.9783457	total: 1m 22s	remaining: 7m 58s
# 59:	learn: 0.9782094	total: 1m 24s	remaining: 7m 58s
# 60:	learn: 0.9778581	total: 1m 24s	remaining: 7m 51s
# 61:	learn: 0.9779370	total: 1m 26s	remaining: 7m 50s
# 62:	learn: 0.9776645	total: 1m 27s	remaining: 7m 49s
# 63:	learn: 0.9776645	total: 1m 29s	remaining: 7m 50s
# 64:	learn: 0.9775569	total: 1m 30s	remaining: 7m 47s
# 65:	learn: 0.9773705	total: 1m 32s	remaining: 7m 46s
# 66:	learn: 0.9779370	total: 1m 33s	remaining: 7m 44s
# 67:	learn: 0.9776860	total: 1m 34s	remaining: 7m 43s
# 68:	learn: 0.9781377	total: 1m 36s	remaining: 7m 41s
# 69:	learn: 0.9787185	total: 1m 37s	remaining: 7m 39s
# 70:	learn: 0.9785106	total: 1m 37s	remaining: 7m 32s
# 71:	learn: 0.9781306	total: 1m 38s	remaining: 7m 27s
# 72:	learn: 0.9780517	total: 1m 39s	remaining: 7m 26s
# 73:	learn: 0.9781521	total: 1m 41s	remaining: 7m 25s
# 74:	learn: 0.9787615	total: 1m 42s	remaining: 7m 24s
# 75:	learn: 0.9788117	total: 1m 43s	remaining: 7m 22s
# 76:	learn: 0.9784532	total: 1m 45s	remaining: 7m 21s
# 77:	learn: 0.9779872	total: 1m 45s	remaining: 7m 14s
# 78:	learn: 0.9780445	total: 1m 46s	remaining: 7m 12s
# 79:	learn: 0.9779943	total: 1m 47s	remaining: 7m 11s
# 80:	learn: 0.9779370	total: 1m 49s	remaining: 7m 10s
# 81:	learn: 0.9778366	total: 1m 50s	remaining: 7m 9s
# 82:	learn: 0.9780517	total: 1m 51s	remaining: 7m 7s
# 83:	learn: 0.9777936	total: 1m 53s	remaining: 7m 6s
# 84:	learn: 0.9777290	total: 1m 54s	remaining: 7m 4s
# 85:	learn: 0.9774494	total: 1m 56s	remaining: 7m 3s
# 86:	learn: 0.9773203	total: 1m 57s	remaining: 7m 2s
# 87:	learn: 0.9775426	total: 1m 58s	remaining: 7m
# 88:	learn: 0.9776000	total: 1m 59s	remaining: 6m 58s
# 89:	learn: 0.9775139	total: 2m 1s	remaining: 6m 58s
# 90:	learn: 0.9778724	total: 2m 3s	remaining: 6m 58s
# 91:	learn: 0.9777864	total: 2m 4s	remaining: 6m 56s
# 92:	learn: 0.9779083	total: 2m 5s	remaining: 6m 55s
# 93:	learn: 0.9777936	total: 2m 7s	remaining: 6m 55s
# 94:	learn: 0.9777434	total: 2m 8s	remaining: 6m 54s
# 95:	learn: 0.9783887	total: 2m 10s	remaining: 6m 54s
# 96:	learn: 0.9783385	total: 2m 12s	remaining: 6m 54s
# 97:	learn: 0.9783528	total: 2m 13s	remaining: 6m 52s
# 98:	learn: 0.9783959	total: 2m 15s	remaining: 6m 51s
# 99:	learn: 0.9783528	total: 2m 16s	remaining: 6m 50s
# 100:	learn: 0.9783098	total: 2m 18s	remaining: 6m 49s
# 101:	learn: 0.9782668	total: 2m 20s	remaining: 6m 49s
# 102:	learn: 0.9780517	total: 2m 21s	remaining: 6m 49s
# 103:	learn: 0.9782740	total: 2m 23s	remaining: 6m 49s
# 104:	learn: 0.9786898	total: 2m 25s	remaining: 6m 48s
# 105:	learn: 0.9786253	total: 2m 26s	remaining: 6m 47s
# 106:	learn: 0.9783385	total: 2m 28s	remaining: 6m 46s
# 107:	learn: 0.9782094	total: 2m 30s	remaining: 6m 45s
# 108:	learn: 0.9783026	total: 2m 31s	remaining: 6m 44s
# 109:	learn: 0.9783457	total: 2m 33s	remaining: 6m 43s
# 110:	learn: 0.9784389	total: 2m 34s	remaining: 6m 42s
# 111:	learn: 0.9785321	total: 2m 36s	remaining: 6m 41s
# 112:	learn: 0.9785966	total: 2m 37s	remaining: 6m 39s
# 113:	learn: 0.9786181	total: 2m 38s	remaining: 6m 38s
# 114:	learn: 0.9787257	total: 2m 40s	remaining: 6m 36s
# 115:	learn: 0.9786396	total: 2m 42s	remaining: 6m 36s
# 116:	learn: 0.9786396	total: 2m 43s	remaining: 6m 36s
# 117:	learn: 0.9789551	total: 2m 45s	remaining: 6m 36s
# 118:	learn: 0.9795503	total: 2m 47s	remaining: 6m 34s
# 119:	learn: 0.9798514	total: 2m 48s	remaining: 6m 33s
# 120:	learn: 0.9796865	total: 2m 49s	remaining: 6m 31s
# 121:	learn: 0.9796005	total: 2m 51s	remaining: 6m 30s
# 122:	learn: 0.9797295	total: 2m 53s	remaining: 6m 30s
# 123:	learn: 0.9799016	total: 2m 55s	remaining: 6m 29s
# 124:	learn: 0.9805900	total: 2m 56s	remaining: 6m 28s
# 125:	learn: 0.9807907	total: 2m 58s	remaining: 6m 28s
# 126:	learn: 0.9807907	total: 3m	remaining: 6m 28s
# 127:	learn: 0.9806473	total: 3m 2s	remaining: 6m 28s
# 128:	learn: 0.9805685	total: 3m 5s	remaining: 6m 28s
# 129:	learn: 0.9804681	total: 3m 7s	remaining: 6m 28s
# 130:	learn: 0.9804394	total: 3m 9s	remaining: 6m 29s
# 131:	learn: 0.9805039	total: 3m 12s	remaining: 6m 30s
# 132:	learn: 0.9805111	total: 3m 13s	remaining: 6m 27s
# 133:	learn: 0.9806115	total: 3m 14s	remaining: 6m 26s
# 134:	learn: 0.9806545	total: 3m 16s	remaining: 6m 25s
# 135:	learn: 0.9805828	total: 3m 18s	remaining: 6m 24s
# 136:	learn: 0.9806545	total: 3m 20s	remaining: 6m 25s
# 137:	learn: 0.9806760	total: 3m 22s	remaining: 6m 24s
# 138:	learn: 0.9806043	total: 3m 25s	remaining: 6m 25s
# 139:	learn: 0.9806832	total: 3m 27s	remaining: 6m 25s
# 140:	learn: 0.9806115	total: 3m 29s	remaining: 6m 25s
# 141:	learn: 0.9807334	total: 3m 31s	remaining: 6m 25s
# 142:	learn: 0.9805685	total: 3m 32s	remaining: 6m 21s
# 143:	learn: 0.9807405	total: 3m 33s	remaining: 6m 19s
# 144:	learn: 0.9807549	total: 3m 35s	remaining: 6m 19s
# 145:	learn: 0.9808409	total: 3m 37s	remaining: 6m 17s
# 146:	learn: 0.9807334	total: 3m 37s	remaining: 6m 13s
# 147:	learn: 0.9808983	total: 3m 38s	remaining: 6m 12s
# 148:	learn: 0.9807262	total: 3m 40s	remaining: 6m 11s
# 149:	learn: 0.9809915	total: 3m 41s	remaining: 6m 9s
# 150:	learn: 0.9808338	total: 3m 43s	remaining: 6m 8s
# 151:	learn: 0.9811923	total: 3m 45s	remaining: 6m 7s
# 152:	learn: 0.9811994	total: 3m 47s	remaining: 6m 6s
# 153:	learn: 0.9811779	total: 3m 48s	remaining: 6m 5s
# 154:	learn: 0.9813859	total: 3m 50s	remaining: 6m 4s
# 155:	learn: 0.9815078	total: 3m 51s	remaining: 6m 2s
# 156:	learn: 0.9812568	total: 3m 53s	remaining: 6m 1s
# 157:	learn: 0.9813787	total: 3m 54s	remaining: 5m 59s
# 158:	learn: 0.9815508	total: 3m 56s	remaining: 5m 58s
# 159:	learn: 0.9815149	total: 3m 58s	remaining: 5m 57s
# 160:	learn: 0.9816799	total: 4m	remaining: 5m 56s
# 161:	learn: 0.9817372	total: 4m 1s	remaining: 5m 55s
# 162:	learn: 0.9818519	total: 4m 3s	remaining: 5m 54s
# 163:	learn: 0.9819380	total: 4m 5s	remaining: 5m 52s
# 164:	learn: 0.9818878	total: 4m 6s	remaining: 5m 51s
# 165:	learn: 0.9818304	total: 4m 8s	remaining: 5m 50s
# 166:	learn: 0.9818089	total: 4m 10s	remaining: 5m 49s
# 167:	learn: 0.9816655	total: 4m 12s	remaining: 5m 48s
# 168:	learn: 0.9818663	total: 4m 13s	remaining: 5m 47s
# 169:	learn: 0.9822678	total: 4m 15s	remaining: 5m 46s
# 170:	learn: 0.9820957	total: 4m 17s	remaining: 5m 44s
# 171:	learn: 0.9822176	total: 4m 18s	remaining: 5m 43s
# 172:	learn: 0.9823467	total: 4m 20s	remaining: 5m 41s
# 173:	learn: 0.9823682	total: 4m 22s	remaining: 5m 41s
# 174:	learn: 0.9823539	total: 4m 24s	remaining: 5m 40s
# 175:	learn: 0.9823897	total: 4m 27s	remaining: 5m 39s
# 176:	learn: 0.9824471	total: 4m 29s	remaining: 5m 39s
# 177:	learn: 0.9824327	total: 4m 31s	remaining: 5m 38s
# 178:	learn: 0.9825618	total: 4m 33s	remaining: 5m 37s
# 179:	learn: 0.9828773	total: 4m 34s	remaining: 5m 35s
# 180:	learn: 0.9829060	total: 4m 36s	remaining: 5m 34s
# 181:	learn: 0.9831068	total: 4m 38s	remaining: 5m 33s
# 182:	learn: 0.9832358	total: 4m 39s	remaining: 5m 31s
# 183:	learn: 0.9832358	total: 4m 41s	remaining: 5m 30s
# 184:	learn: 0.9832143	total: 4m 43s	remaining: 5m 28s
# 185:	learn: 0.9832860	total: 4m 44s	remaining: 5m 27s
# 186:	learn: 0.9832502	total: 4m 46s	remaining: 5m 25s
# 187:	learn: 0.9831068	total: 4m 47s	remaining: 5m 24s
# 188:	learn: 0.9831498	total: 4m 49s	remaining: 5m 23s
# 189:	learn: 0.9830924	total: 4m 49s	remaining: 5m 20s
# 190:	learn: 0.9829849	total: 4m 50s	remaining: 5m 17s
# 191:	learn: 0.9829347	total: 4m 51s	remaining: 5m 16s
# 192:	learn: 0.9830494	total: 4m 53s	remaining: 5m 14s
# 193:	learn: 0.9831426	total: 4m 54s	remaining: 5m 12s
# 194:	learn: 0.9833792	total: 4m 56s	remaining: 5m 11s
# 195:	learn: 0.9834294	total: 4m 57s	remaining: 5m 9s
# 196:	learn: 0.9833936	total: 4m 58s	remaining: 5m 7s
# 197:	learn: 0.9833792	total: 5m	remaining: 5m 6s
# 198:	learn: 0.9834222	total: 5m 1s	remaining: 5m 4s
# 199:	learn: 0.9835011	total: 5m 3s	remaining: 5m 3s
# 200:	learn: 0.9836087	total: 5m 4s	remaining: 5m 1s
# 201:	learn: 0.9834294	total: 5m 4s	remaining: 4m 58s
# 202:	learn: 0.9835872	total: 5m 5s	remaining: 4m 56s
# 203:	learn: 0.9835370	total: 5m 7s	remaining: 4m 55s
# 204:	learn: 0.9835441	total: 5m 8s	remaining: 4m 53s
# 205:	learn: 0.9834509	total: 5m 10s	remaining: 4m 52s
# 206:	learn: 0.9834007	total: 5m 10s	remaining: 4m 49s
# 207:	learn: 0.9833864	total: 5m 12s	remaining: 4m 48s
# 208:	learn: 0.9833290	total: 5m 13s	remaining: 4m 46s
# 209:	learn: 0.9833219	total: 5m 14s	remaining: 4m 44s
# 210:	learn: 0.9834294	total: 5m 16s	remaining: 4m 43s
# 211:	learn: 0.9834007	total: 5m 17s	remaining: 4m 41s
# 212:	learn: 0.9833649	total: 5m 18s	remaining: 4m 39s
# 213:	learn: 0.9834438	total: 5m 20s	remaining: 4m 38s
# 214:	learn: 0.9834796	total: 5m 21s	remaining: 4m 37s
# 215:	learn: 0.9834222	total: 5m 22s	remaining: 4m 34s
# 216:	learn: 0.9833936	total: 5m 23s	remaining: 4m 33s
# 217:	learn: 0.9833864	total: 5m 25s	remaining: 4m 32s
# 218:	learn: 0.9833362	total: 5m 28s	remaining: 4m 31s
# 219:	learn: 0.9832502	total: 5m 30s	remaining: 4m 30s
# 220:	learn: 0.9831641	total: 5m 31s	remaining: 4m 28s
# 221:	learn: 0.9831785	total: 5m 33s	remaining: 4m 27s
# 222:	learn: 0.9831498	total: 5m 35s	remaining: 4m 25s
# 223:	learn: 0.9834007	total: 5m 36s	remaining: 4m 24s
# 224:	learn: 0.9833936	total: 5m 38s	remaining: 4m 23s
# 225:	learn: 0.9833434	total: 5m 39s	remaining: 4m 21s
# 226:	learn: 0.9835872	total: 5m 41s	remaining: 4m 20s
# 227:	learn: 0.9835226	total: 5m 42s	remaining: 4m 18s
# 228:	learn: 0.9835585	total: 5m 44s	remaining: 4m 17s
# 229:	learn: 0.9835011	total: 5m 46s	remaining: 4m 15s
# 230:	learn: 0.9835011	total: 5m 47s	remaining: 4m 14s
# 231:	learn: 0.9834796	total: 5m 48s	remaining: 4m 12s
# 232:	learn: 0.9835155	total: 5m 50s	remaining: 4m 11s
# 233:	learn: 0.9835370	total: 5m 51s	remaining: 4m 9s
# 234:	learn: 0.9835370	total: 5m 53s	remaining: 4m 8s
# 235:	learn: 0.9835370	total: 5m 54s	remaining: 4m 6s
# 236:	learn: 0.9835513	total: 5m 56s	remaining: 4m 4s
# 237:	learn: 0.9836589	total: 5m 57s	remaining: 4m 3s
# 238:	learn: 0.9835943	total: 5m 58s	remaining: 4m 1s
# 239:	learn: 0.9837019	total: 5m 59s	remaining: 3m 59s
# 240:	learn: 0.9837377	total: 6m 1s	remaining: 3m 58s
# 241:	learn: 0.9837234	total: 6m 2s	remaining: 3m 56s
# 242:	learn: 0.9837736	total: 6m 4s	remaining: 3m 55s
# 243:	learn: 0.9837879	total: 6m 5s	remaining: 3m 53s
# 244:	learn: 0.9838811	total: 6m 6s	remaining: 3m 52s
# 245:	learn: 0.9839744	total: 6m 8s	remaining: 3m 50s
# 246:	learn: 0.9839313	total: 6m 9s	remaining: 3m 49s
# 247:	learn: 0.9839600	total: 6m 11s	remaining: 3m 47s
# 248:	learn: 0.9839887	total: 6m 13s	remaining: 3m 46s
# 249:	learn: 0.9839457	total: 6m 15s	remaining: 3m 45s
# 250:	learn: 0.9840532	total: 6m 16s	remaining: 3m 43s
# 251:	learn: 0.9840246	total: 6m 18s	remaining: 3m 42s
# 252:	learn: 0.9840389	total: 6m 18s	remaining: 3m 39s
# 253:	learn: 0.9839887	total: 6m 20s	remaining: 3m 38s
# 254:	learn: 0.9839528	total: 6m 21s	remaining: 3m 37s
# 255:	learn: 0.9840102	total: 6m 23s	remaining: 3m 35s
# 256:	learn: 0.9839528	total: 6m 24s	remaining: 3m 34s
# 257:	learn: 0.9840604	total: 6m 26s	remaining: 3m 32s
# 258:	learn: 0.9841249	total: 6m 27s	remaining: 3m 31s
# 259:	learn: 0.9841321	total: 6m 29s	remaining: 3m 29s
# 260:	learn: 0.9842038	total: 6m 31s	remaining: 3m 28s
# 261:	learn: 0.9841034	total: 6m 32s	remaining: 3m 26s
# 262:	learn: 0.9841249	total: 6m 34s	remaining: 3m 25s
# 263:	learn: 0.9840246	total: 6m 36s	remaining: 3m 24s
# 264:	learn: 0.9840389	total: 6m 38s	remaining: 3m 22s
# 265:	learn: 0.9838955	total: 6m 39s	remaining: 3m 21s
# 266:	learn: 0.9840174	total: 6m 41s	remaining: 3m 19s
# 267:	learn: 0.9839170	total: 6m 42s	remaining: 3m 18s
# 268:	learn: 0.9838740	total: 6m 44s	remaining: 3m 17s
# 269:	learn: 0.9838596	total: 6m 46s	remaining: 3m 15s
# 270:	learn: 0.9838955	total: 6m 47s	remaining: 3m 14s
# 271:	learn: 0.9838453	total: 6m 49s	remaining: 3m 12s
# 272:	learn: 0.9839457	total: 6m 51s	remaining: 3m 11s
# 273:	learn: 0.9838668	total: 6m 52s	remaining: 3m 9s
# 274:	learn: 0.9838883	total: 6m 52s	remaining: 3m 7s
# 275:	learn: 0.9838883	total: 6m 54s	remaining: 3m 6s
# 276:	learn: 0.9838310	total: 6m 55s	remaining: 3m 4s
# 277:	learn: 0.9839170	total: 6m 56s	remaining: 3m 2s
# 278:	learn: 0.9840246	total: 6m 58s	remaining: 3m 1s
# 279:	learn: 0.9840246	total: 6m 58s	remaining: 2m 59s
# 280:	learn: 0.9840819	total: 6m 58s	remaining: 2m 57s
# 281:	learn: 0.9841178	total: 7m	remaining: 2m 55s
# 282:	learn: 0.9841321	total: 7m 1s	remaining: 2m 54s
# 283:	learn: 0.9840819	total: 7m 2s	remaining: 2m 52s
# 284:	learn: 0.9840747	total: 7m 4s	remaining: 2m 51s
# 285:	learn: 0.9840102	total: 7m 5s	remaining: 2m 49s
# 286:	learn: 0.9841751	total: 7m 7s	remaining: 2m 48s
# 287:	learn: 0.9842899	total: 7m 8s	remaining: 2m 46s
# 288:	learn: 0.9843329	total: 7m 9s	remaining: 2m 45s
# 289:	learn: 0.9845050	total: 7m 11s	remaining: 2m 43s
# 290:	learn: 0.9845193	total: 7m 12s	remaining: 2m 41s
# 291:	learn: 0.9845480	total: 7m 13s	remaining: 2m 40s
# 292:	learn: 0.9847703	total: 7m 15s	remaining: 2m 38s
# 293:	learn: 0.9848420	total: 7m 16s	remaining: 2m 37s
# 294:	learn: 0.9847703	total: 7m 17s	remaining: 2m 35s
# 295:	learn: 0.9846842	total: 7m 19s	remaining: 2m 34s
# 296:	learn: 0.9847488	total: 7m 20s	remaining: 2m 32s
# 297:	learn: 0.9847488	total: 7m 21s	remaining: 2m 31s
# 298:	learn: 0.9848420	total: 7m 23s	remaining: 2m 29s
# 299:	learn: 0.9847989	total: 7m 23s	remaining: 2m 27s
# 300:	learn: 0.9849782	total: 7m 25s	remaining: 2m 26s
# 301:	learn: 0.9849424	total: 7m 26s	remaining: 2m 24s
# 302:	learn: 0.9849710	total: 7m 27s	remaining: 2m 23s
# 303:	learn: 0.9849495	total: 7m 29s	remaining: 2m 21s
# 304:	learn: 0.9849065	total: 7m 30s	remaining: 2m 20s
# 305:	learn: 0.9849710	total: 7m 32s	remaining: 2m 18s
# 306:	learn: 0.9850642	total: 7m 33s	remaining: 2m 17s
# 307:	learn: 0.9850642	total: 7m 34s	remaining: 2m 15s
# 308:	learn: 0.9850212	total: 7m 36s	remaining: 2m 14s
# 309:	learn: 0.9850786	total: 7m 37s	remaining: 2m 12s
# 310:	learn: 0.9851288	total: 7m 39s	remaining: 2m 11s
# 311:	learn: 0.9851861	total: 7m 40s	remaining: 2m 9s
# 312:	learn: 0.9852005	total: 7m 42s	remaining: 2m 8s
# 313:	learn: 0.9852148	total: 7m 43s	remaining: 2m 6s
# 314:	learn: 0.9852005	total: 7m 44s	remaining: 2m 5s
# 315:	learn: 0.9852148	total: 7m 46s	remaining: 2m 3s
# 316:	learn: 0.9853152	total: 7m 47s	remaining: 2m 2s
# 317:	learn: 0.9853654	total: 7m 49s	remaining: 2m
# 318:	learn: 0.9852865	total: 7m 50s	remaining: 1m 59s
# 319:	learn: 0.9853080	total: 7m 51s	remaining: 1m 57s
# 320:	learn: 0.9853511	total: 7m 53s	remaining: 1m 56s
# 321:	learn: 0.9853367	total: 7m 54s	remaining: 1m 54s
# 322:	learn: 0.9852937	total: 7m 56s	remaining: 1m 53s
# 323:	learn: 0.9853295	total: 7m 57s	remaining: 1m 52s
# 324:	learn: 0.9853367	total: 7m 58s	remaining: 1m 50s
# 325:	learn: 0.9854013	total: 8m	remaining: 1m 48s
# 326:	learn: 0.9853367	total: 8m	remaining: 1m 47s
# 327:	learn: 0.9853295	total: 8m 2s	remaining: 1m 45s
# 328:	learn: 0.9853224	total: 8m 3s	remaining: 1m 44s
# 329:	learn: 0.9853797	total: 8m 5s	remaining: 1m 42s
# 330:	learn: 0.9854371	total: 8m 6s	remaining: 1m 41s
# 331:	learn: 0.9854371	total: 8m 7s	remaining: 1m 39s
# 332:	learn: 0.9854084	total: 8m 9s	remaining: 1m 38s
# 333:	learn: 0.9853869	total: 8m 11s	remaining: 1m 37s
# 334:	learn: 0.9854228	total: 8m 12s	remaining: 1m 35s
# 335:	learn: 0.9854299	total: 8m 14s	remaining: 1m 34s
# 336:	learn: 0.9854801	total: 8m 15s	remaining: 1m 32s
# 337:	learn: 0.9855160	total: 8m 16s	remaining: 1m 31s
# 338:	learn: 0.9856379	total: 8m 17s	remaining: 1m 29s
# 339:	learn: 0.9857096	total: 8m 19s	remaining: 1m 28s
# 340:	learn: 0.9857311	total: 8m 20s	remaining: 1m 26s
# 341:	learn: 0.9857526	total: 8m 22s	remaining: 1m 25s
# 342:	learn: 0.9858100	total: 8m 24s	remaining: 1m 23s
# 343:	learn: 0.9857813	total: 8m 25s	remaining: 1m 22s
# 344:	learn: 0.9858386	total: 8m 27s	remaining: 1m 20s
# 345:	learn: 0.9858171	total: 8m 28s	remaining: 1m 19s
# 346:	learn: 0.9858602	total: 8m 29s	remaining: 1m 17s
# 347:	learn: 0.9859605	total: 8m 31s	remaining: 1m 16s
# 348:	learn: 0.9859462	total: 8m 32s	remaining: 1m 14s
# 349:	learn: 0.9859175	total: 8m 34s	remaining: 1m 13s
# 350:	learn: 0.9859820	total: 8m 35s	remaining: 1m 11s
# 351:	learn: 0.9860537	total: 8m 36s	remaining: 1m 10s
# 352:	learn: 0.9861111	total: 8m 38s	remaining: 1m 8s
# 353:	learn: 0.9861685	total: 8m 39s	remaining: 1m 7s
# 354:	learn: 0.9861756	total: 8m 40s	remaining: 1m 6s
# 355:	learn: 0.9862473	total: 8m 42s	remaining: 1m 4s
# 356:	learn: 0.9861756	total: 8m 43s	remaining: 1m 3s
# 357:	learn: 0.9864194	total: 8m 44s	remaining: 1m 1s
# 358:	learn: 0.9863908	total: 8m 46s	remaining: 1m
# 359:	learn: 0.9863979	total: 8m 47s	remaining: 58.6s
# 360:	learn: 0.9864123	total: 8m 48s	remaining: 57.1s
# 361:	learn: 0.9863908	total: 8m 49s	remaining: 55.5s
# 362:	learn: 0.9863764	total: 8m 50s	remaining: 54.1s
# 363:	learn: 0.9864123	total: 8m 52s	remaining: 52.6s
# 364:	learn: 0.9864625	total: 8m 53s	remaining: 51.1s
# 365:	learn: 0.9864553	total: 8m 54s	remaining: 49.7s
# 366:	learn: 0.9865700	total: 8m 56s	remaining: 48.2s
# 367:	learn: 0.9865915	total: 8m 57s	remaining: 46.7s
# 368:	learn: 0.9865270	total: 8m 57s	remaining: 45.1s
# 369:	learn: 0.9865628	total: 8m 58s	remaining: 43.7s
# 370:	learn: 0.9864983	total: 9m	remaining: 42.3s
# 371:	learn: 0.9865772	total: 9m 1s	remaining: 40.8s
# 372:	learn: 0.9866991	total: 9m 3s	remaining: 39.3s
# 373:	learn: 0.9867636	total: 9m 4s	remaining: 37.9s
# 374:	learn: 0.9867708	total: 9m 6s	remaining: 36.4s
# 375:	learn: 0.9867851	total: 9m 7s	remaining: 34.9s
# 376:	learn: 0.9867995	total: 9m 8s	remaining: 33.5s
# 377:	learn: 0.9867851	total: 9m 9s	remaining: 32s
# 378:	learn: 0.9867779	total: 9m 11s	remaining: 30.6s
# 379:	learn: 0.9867995	total: 9m 12s	remaining: 29.1s
# 380:	learn: 0.9868210	total: 9m 14s	remaining: 27.6s
# 381:	learn: 0.9868425	total: 9m 15s	remaining: 26.2s
# 382:	learn: 0.9868855	total: 9m 16s	remaining: 24.7s
# 383:	learn: 0.9869214	total: 9m 18s	remaining: 23.3s
# 384:	learn: 0.9869142	total: 9m 19s	remaining: 21.8s
# 385:	learn: 0.9869572	total: 9m 21s	remaining: 20.4s
# 386:	learn: 0.9870934	total: 9m 22s	remaining: 18.9s
# 387:	learn: 0.9870289	total: 9m 24s	remaining: 17.5s
# 388:	learn: 0.9870361	total: 9m 25s	remaining: 16s
# 389:	learn: 0.9870217	total: 9m 26s	remaining: 14.5s
# 390:	learn: 0.9870791	total: 9m 28s	remaining: 13.1s
# 391:	learn: 0.9870289	total: 9m 30s	remaining: 11.6s
# 392:	learn: 0.9870791	total: 9m 31s	remaining: 10.2s
# 393:	learn: 0.9870433	total: 9m 32s	remaining: 8.72s
# 394:	learn: 0.9871221	total: 9m 34s	remaining: 7.27s
# 395:	learn: 0.9871365	total: 9m 35s	remaining: 5.81s
# 396:	learn: 0.9871293	total: 9m 36s	remaining: 4.36s
# 397:	learn: 0.9872153	total: 9m 38s	remaining: 2.91s
# 398:	learn: 0.9872368	total: 9m 40s	remaining: 1.45s
# 399:	learn: 0.9872512	total: 9m 41s	remaining: 0us
# Train ROC AUC: 0.9873
# Holdout ROC AUC: 0.8451
# CPU times: user 23min 31s, sys: 4min 25s, total: 27min 56s
# Wall time: 9min 56s

# %%
pipe_cat.fit(X, y)

submission = pd.read_csv(submission_file)
submission['y'] = pipe_cat.predict_proba(X_test)[:,1]
submission.to_csv('submission_cat_modified_3.csv', index=False)
# Out:
# 0:	learn: 0.8694904	total: 1.82s	remaining: 12m 8s
# 1:	learn: 0.8961948	total: 3.88s	remaining: 12m 51s
# 2:	learn: 0.8954883	total: 5.32s	remaining: 11m 44s
# 3:	learn: 0.8979452	total: 6.71s	remaining: 11m 4s
# 4:	learn: 0.9009961	total: 8.09s	remaining: 10m 39s
# 5:	learn: 0.9097236	total: 9.4s	remaining: 10m 17s
# 6:	learn: 0.9147956	total: 10.9s	remaining: 10m 9s
# 7:	learn: 0.9233262	total: 12.6s	remaining: 10m 16s
# 8:	learn: 0.9295792	total: 14s	remaining: 10m 8s
# 9:	learn: 0.9316793	total: 16s	remaining: 10m 22s
# 10:	learn: 0.9321714	total: 17.6s	remaining: 10m 23s
# 11:	learn: 0.9397653	total: 19s	remaining: 10m 14s
# 12:	learn: 0.9393998	total: 20.3s	remaining: 10m 3s
# 13:	learn: 0.9422223	total: 22.1s	remaining: 10m 10s
# 14:	learn: 0.9462468	total: 23.8s	remaining: 10m 10s
# 15:	learn: 0.9483803	total: 25.7s	remaining: 10m 16s
# 16:	learn: 0.9490236	total: 27.3s	remaining: 10m 14s
# 17:	learn: 0.9518759	total: 28.6s	remaining: 10m 7s
# 18:	learn: 0.9519919	total: 29.9s	remaining: 9m 58s
# 19:	learn: 0.9531799	total: 31.1s	remaining: 9m 50s
# 20:	learn: 0.9544699	total: 32.4s	remaining: 9m 43s
# 21:	learn: 0.9551272	total: 33.6s	remaining: 9m 38s
# 22:	learn: 0.9559672	total: 35.6s	remaining: 9m 42s
# 23:	learn: 0.9556579	total: 37.1s	remaining: 9m 40s
# 24:	learn: 0.9543750	total: 38.6s	remaining: 9m 38s
# 25:	learn: 0.9550235	total: 40.2s	remaining: 9m 37s
# 26:	learn: 0.9552976	total: 41.7s	remaining: 9m 36s
# 27:	learn: 0.9554945	total: 43.2s	remaining: 9m 34s
# 28:	learn: 0.9562642	total: 44.6s	remaining: 9m 30s
# 29:	learn: 0.9564681	total: 46.9s	remaining: 9m 38s
# 30:	learn: 0.9566649	total: 48.3s	remaining: 9m 34s
# 31:	learn: 0.9570762	total: 49.9s	remaining: 9m 33s
# 32:	learn: 0.9577616	total: 51.8s	remaining: 9m 35s
# 33:	learn: 0.9583275	total: 53.6s	remaining: 9m 36s
# 34:	learn: 0.9580533	total: 55s	remaining: 9m 33s
# 35:	learn: 0.9586544	total: 56.1s	remaining: 9m 26s
# 36:	learn: 0.9581728	total: 56.4s	remaining: 9m 12s
# 37:	learn: 0.9587528	total: 57.8s	remaining: 9m 10s
# 38:	learn: 0.9590937	total: 59.1s	remaining: 9m 7s
# 39:	learn: 0.9588969	total: 1m	remaining: 9m 5s
# 40:	learn: 0.9607000	total: 1m 2s	remaining: 9m 4s
# 41:	learn: 0.9600990	total: 1m 3s	remaining: 9m 3s
# 42:	learn: 0.9605840	total: 1m 5s	remaining: 9m 1s
# 43:	learn: 0.9602923	total: 1m 6s	remaining: 8m 58s
# 44:	learn: 0.9606016	total: 1m 7s	remaining: 8m 54s
# 45:	learn: 0.9610831	total: 1m 9s	remaining: 8m 51s
# 46:	learn: 0.9606965	total: 1m 10s	remaining: 8m 49s
# 47:	learn: 0.9606508	total: 1m 11s	remaining: 8m 47s
# 48:	learn: 0.9608406	total: 1m 13s	remaining: 8m 48s
# 49:	learn: 0.9607984	total: 1m 15s	remaining: 8m 46s
# 50:	learn: 0.9604856	total: 1m 16s	remaining: 8m 43s
# 51:	learn: 0.9605700	total: 1m 17s	remaining: 8m 41s
# 52:	learn: 0.9611921	total: 1m 19s	remaining: 8m 39s
# 53:	learn: 0.9612835	total: 1m 20s	remaining: 8m 36s
# 54:	learn: 0.9612765	total: 1m 21s	remaining: 8m 34s
# 55:	learn: 0.9618494	total: 1m 23s	remaining: 8m 31s
# 56:	learn: 0.9622712	total: 1m 24s	remaining: 8m 29s
# 57:	learn: 0.9626543	total: 1m 25s	remaining: 8m 26s
# 58:	learn: 0.9625207	total: 1m 27s	remaining: 8m 24s
# 59:	learn: 0.9631148	total: 1m 28s	remaining: 8m 23s
# 60:	learn: 0.9631183	total: 1m 30s	remaining: 8m 21s
# 61:	learn: 0.9640040	total: 1m 31s	remaining: 8m 20s
# 62:	learn: 0.9644574	total: 1m 33s	remaining: 8m 19s
# 63:	learn: 0.9638248	total: 1m 35s	remaining: 8m 18s
# 64:	learn: 0.9639126	total: 1m 36s	remaining: 8m 16s
# 65:	learn: 0.9641060	total: 1m 37s	remaining: 8m 14s
# 66:	learn: 0.9648792	total: 1m 39s	remaining: 8m 13s
# 67:	learn: 0.9648757	total: 1m 40s	remaining: 8m 12s
# 68:	learn: 0.9651007	total: 1m 42s	remaining: 8m 11s
# 69:	learn: 0.9650479	total: 1m 43s	remaining: 8m 9s
# 70:	learn: 0.9654732	total: 1m 45s	remaining: 8m 9s
# 71:	learn: 0.9652905	total: 1m 47s	remaining: 8m 7s
# 72:	learn: 0.9651288	total: 1m 47s	remaining: 8m 2s
# 73:	learn: 0.9650163	total: 1m 49s	remaining: 8m 1s
# 74:	learn: 0.9649530	total: 1m 50s	remaining: 8m
# 75:	learn: 0.9647457	total: 1m 52s	remaining: 8m
# 76:	learn: 0.9653080	total: 1m 54s	remaining: 7m 58s
# 77:	learn: 0.9652659	total: 1m 55s	remaining: 7m 56s
# 78:	learn: 0.9653537	total: 1m 56s	remaining: 7m 54s
# 79:	learn: 0.9657826	total: 1m 58s	remaining: 7m 54s
# 80:	learn: 0.9657931	total: 2m	remaining: 7m 52s
# 81:	learn: 0.9662571	total: 2m 1s	remaining: 7m 51s
# 82:	learn: 0.9660743	total: 2m 3s	remaining: 7m 50s
# 83:	learn: 0.9662430	total: 2m 3s	remaining: 7m 45s
# 84:	learn: 0.9662219	total: 2m 5s	remaining: 7m 43s
# 85:	learn: 0.9662289	total: 2m 6s	remaining: 7m 42s
# 86:	learn: 0.9664187	total: 2m 8s	remaining: 7m 41s
# 87:	learn: 0.9663344	total: 2m 9s	remaining: 7m 39s
# 88:	learn: 0.9662043	total: 2m 11s	remaining: 7m 38s
# 89:	learn: 0.9661200	total: 2m 12s	remaining: 7m 37s
# 90:	learn: 0.9663238	total: 2m 14s	remaining: 7m 35s
# 91:	learn: 0.9668300	total: 2m 15s	remaining: 7m 33s
# 92:	learn: 0.9667175	total: 2m 17s	remaining: 7m 33s
# 93:	learn: 0.9665383	total: 2m 20s	remaining: 7m 36s
# 94:	learn: 0.9667702	total: 2m 22s	remaining: 7m 37s
# 95:	learn: 0.9672483	total: 2m 23s	remaining: 7m 35s
# 96:	learn: 0.9674802	total: 2m 25s	remaining: 7m 35s
# 97:	learn: 0.9676665	total: 2m 27s	remaining: 7m 33s
# 98:	learn: 0.9673783	total: 2m 28s	remaining: 7m 31s
# 99:	learn: 0.9674838	total: 2m 29s	remaining: 7m 29s
# 100:	learn: 0.9673713	total: 2m 31s	remaining: 7m 28s
# 101:	learn: 0.9670303	total: 2m 32s	remaining: 7m 26s
# 102:	learn: 0.9672553	total: 2m 34s	remaining: 7m 24s
# 103:	learn: 0.9671358	total: 2m 35s	remaining: 7m 22s
# 104:	learn: 0.9672975	total: 2m 36s	remaining: 7m 20s
# 105:	learn: 0.9672483	total: 2m 38s	remaining: 7m 19s
# 106:	learn: 0.9672588	total: 2m 39s	remaining: 7m 17s
# 107:	learn: 0.9671428	total: 2m 41s	remaining: 7m 15s
# 108:	learn: 0.9675189	total: 2m 42s	remaining: 7m 14s
# 109:	learn: 0.9673397	total: 2m 44s	remaining: 7m 12s
# 110:	learn: 0.9672869	total: 2m 45s	remaining: 7m 10s
# 111:	learn: 0.9673010	total: 2m 46s	remaining: 7m 8s
# 112:	learn: 0.9672623	total: 2m 48s	remaining: 7m 7s
# 113:	learn: 0.9672131	total: 2m 49s	remaining: 7m 5s
# 114:	learn: 0.9670198	total: 2m 50s	remaining: 7m 2s
# 115:	learn: 0.9671991	total: 2m 51s	remaining: 7m
# 116:	learn: 0.9671604	total: 2m 53s	remaining: 6m 58s
# 117:	learn: 0.9674697	total: 2m 54s	remaining: 6m 56s
# 118:	learn: 0.9671604	total: 2m 55s	remaining: 6m 55s
# 119:	learn: 0.9671147	total: 2m 57s	remaining: 6m 54s
# 120:	learn: 0.9668968	total: 2m 58s	remaining: 6m 51s
# 121:	learn: 0.9669354	total: 2m 59s	remaining: 6m 48s
# 122:	learn: 0.9671323	total: 3m	remaining: 6m 46s
# 123:	learn: 0.9670620	total: 3m 2s	remaining: 6m 45s
# 124:	learn: 0.9670831	total: 3m 3s	remaining: 6m 44s
# 125:	learn: 0.9673256	total: 3m 5s	remaining: 6m 42s
# 126:	learn: 0.9670585	total: 3m 6s	remaining: 6m 40s
# 127:	learn: 0.9672834	total: 3m 7s	remaining: 6m 38s
# 128:	learn: 0.9675857	total: 3m 9s	remaining: 6m 37s
# 129:	learn: 0.9675751	total: 3m 10s	remaining: 6m 35s
# 130:	learn: 0.9675787	total: 3m 11s	remaining: 6m 33s
# 131:	learn: 0.9677368	total: 3m 13s	remaining: 6m 32s
# 132:	learn: 0.9677298	total: 3m 14s	remaining: 6m 30s
# 133:	learn: 0.9678669	total: 3m 15s	remaining: 6m 28s
# 134:	learn: 0.9678985	total: 3m 17s	remaining: 6m 26s
# 135:	learn: 0.9680391	total: 3m 18s	remaining: 6m 25s
# 136:	learn: 0.9681270	total: 3m 19s	remaining: 6m 23s
# 137:	learn: 0.9680989	total: 3m 20s	remaining: 6m 21s
# 138:	learn: 0.9680426	total: 3m 22s	remaining: 6m 19s
# 139:	learn: 0.9680567	total: 3m 23s	remaining: 6m 17s
# 140:	learn: 0.9679758	total: 3m 24s	remaining: 6m 15s
# 141:	learn: 0.9676419	total: 3m 24s	remaining: 6m 11s
# 142:	learn: 0.9675857	total: 3m 25s	remaining: 6m 10s
# 143:	learn: 0.9676911	total: 3m 27s	remaining: 6m 8s
# 144:	learn: 0.9677685	total: 3m 28s	remaining: 6m 6s
# 145:	learn: 0.9675962	total: 3m 29s	remaining: 6m 5s
# 146:	learn: 0.9678177	total: 3m 31s	remaining: 6m 3s
# 147:	learn: 0.9680145	total: 3m 32s	remaining: 6m 2s
# 148:	learn: 0.9680461	total: 3m 34s	remaining: 6m 1s
# 149:	learn: 0.9679477	total: 3m 35s	remaining: 5m 59s
# 150:	learn: 0.9678739	total: 3m 37s	remaining: 5m 58s
# 151:	learn: 0.9678036	total: 3m 38s	remaining: 5m 56s
# 152:	learn: 0.9678071	total: 3m 40s	remaining: 5m 56s
# 153:	learn: 0.9681094	total: 3m 42s	remaining: 5m 54s
# 154:	learn: 0.9680954	total: 3m 43s	remaining: 5m 52s
# 155:	learn: 0.9681305	total: 3m 44s	remaining: 5m 51s
# 156:	learn: 0.9682500	total: 3m 45s	remaining: 5m 49s
# 157:	learn: 0.9682078	total: 3m 47s	remaining: 5m 47s
# 158:	learn: 0.9682606	total: 3m 48s	remaining: 5m 46s
# 159:	learn: 0.9683098	total: 3m 49s	remaining: 5m 44s
# 160:	learn: 0.9684925	total: 3m 51s	remaining: 5m 43s
# 161:	learn: 0.9684925	total: 3m 52s	remaining: 5m 42s
# 162:	learn: 0.9684258	total: 3m 54s	remaining: 5m 40s
# 163:	learn: 0.9685171	total: 3m 55s	remaining: 5m 39s
# 164:	learn: 0.9686296	total: 3m 56s	remaining: 5m 37s
# 165:	learn: 0.9686366	total: 3m 58s	remaining: 5m 35s
# 166:	learn: 0.9684750	total: 3m 59s	remaining: 5m 34s
# 167:	learn: 0.9685242	total: 4m 1s	remaining: 5m 32s
# 168:	learn: 0.9682957	total: 4m 2s	remaining: 5m 31s
# 169:	learn: 0.9686507	total: 4m 3s	remaining: 5m 29s
# 170:	learn: 0.9685663	total: 4m 5s	remaining: 5m 28s
# 171:	learn: 0.9685277	total: 4m 6s	remaining: 5m 26s
# 172:	learn: 0.9684820	total: 4m 8s	remaining: 5m 25s
# 173:	learn: 0.9684047	total: 4m 9s	remaining: 5m 24s
# 174:	learn: 0.9683062	total: 4m 11s	remaining: 5m 22s
# 175:	learn: 0.9684960	total: 4m 12s	remaining: 5m 21s
# 176:	learn: 0.9685558	total: 4m 14s	remaining: 5m 20s
# 177:	learn: 0.9685171	total: 4m 15s	remaining: 5m 18s
# 178:	learn: 0.9684890	total: 4m 16s	remaining: 5m 17s
# 179:	learn: 0.9686402	total: 4m 18s	remaining: 5m 15s
# 180:	learn: 0.9685523	total: 4m 18s	remaining: 5m 12s
# 181:	learn: 0.9685558	total: 4m 19s	remaining: 5m 11s
# 182:	learn: 0.9684785	total: 4m 21s	remaining: 5m 9s
# 183:	learn: 0.9686085	total: 4m 22s	remaining: 5m 8s
# 184:	learn: 0.9686156	total: 4m 24s	remaining: 5m 6s
# 185:	learn: 0.9686612	total: 4m 26s	remaining: 5m 6s
# 186:	learn: 0.9685804	total: 4m 27s	remaining: 5m 4s
# 187:	learn: 0.9686823	total: 4m 28s	remaining: 5m 2s
# 188:	learn: 0.9687245	total: 4m 30s	remaining: 5m 1s
# 189:	learn: 0.9687351	total: 4m 31s	remaining: 4m 59s
# 190:	learn: 0.9686366	total: 4m 32s	remaining: 4m 58s
# 191:	learn: 0.9687034	total: 4m 34s	remaining: 4m 56s
# 192:	learn: 0.9686894	total: 4m 35s	remaining: 4m 55s
# 193:	learn: 0.9687069	total: 4m 36s	remaining: 4m 54s
# 194:	learn: 0.9685488	total: 4m 38s	remaining: 4m 52s
# 195:	learn: 0.9686261	total: 4m 39s	remaining: 4m 51s
# 196:	learn: 0.9686577	total: 4m 40s	remaining: 4m 49s
# 197:	learn: 0.9687597	total: 4m 42s	remaining: 4m 48s
# 198:	learn: 0.9688581	total: 4m 43s	remaining: 4m 46s
# 199:	learn: 0.9687983	total: 4m 45s	remaining: 4m 45s
# 200:	learn: 0.9687175	total: 4m 46s	remaining: 4m 43s
# 201:	learn: 0.9688651	total: 4m 47s	remaining: 4m 42s
# 202:	learn: 0.9688792	total: 4m 49s	remaining: 4m 40s
# 203:	learn: 0.9689249	total: 4m 50s	remaining: 4m 39s
# 204:	learn: 0.9689495	total: 4m 51s	remaining: 4m 37s
# 205:	learn: 0.9688616	total: 4m 53s	remaining: 4m 36s
# 206:	learn: 0.9688967	total: 4m 55s	remaining: 4m 35s
# 207:	learn: 0.9687667	total: 4m 56s	remaining: 4m 33s
# 208:	learn: 0.9689952	total: 4m 58s	remaining: 4m 32s
# 209:	learn: 0.9688932	total: 4m 58s	remaining: 4m 29s
# 210:	learn: 0.9687843	total: 5m	remaining: 4m 28s
# 211:	learn: 0.9689495	total: 5m 1s	remaining: 4m 27s
# 212:	learn: 0.9689495	total: 5m 2s	remaining: 4m 25s
# 213:	learn: 0.9690268	total: 5m 4s	remaining: 4m 24s
# 214:	learn: 0.9690127	total: 5m 5s	remaining: 4m 22s
# 215:	learn: 0.9690373	total: 5m 6s	remaining: 4m 21s
# 216:	learn: 0.9691147	total: 5m 8s	remaining: 4m 19s
# 217:	learn: 0.9691920	total: 5m 9s	remaining: 4m 18s
# 218:	learn: 0.9692342	total: 5m 11s	remaining: 4m 17s
# 219:	learn: 0.9692553	total: 5m 12s	remaining: 4m 15s
# 220:	learn: 0.9694029	total: 5m 13s	remaining: 4m 14s
# 221:	learn: 0.9693326	total: 5m 15s	remaining: 4m 12s
# 222:	learn: 0.9696524	total: 5m 16s	remaining: 4m 11s
# 223:	learn: 0.9695505	total: 5m 18s	remaining: 4m 10s
# 224:	learn: 0.9695329	total: 5m 20s	remaining: 4m 8s
# 225:	learn: 0.9697614	total: 5m 21s	remaining: 4m 7s
# 226:	learn: 0.9696981	total: 5m 23s	remaining: 4m 6s
# 227:	learn: 0.9697684	total: 5m 24s	remaining: 4m 4s
# 228:	learn: 0.9697438	total: 5m 26s	remaining: 4m 3s
# 229:	learn: 0.9699161	total: 5m 28s	remaining: 4m 2s
# 230:	learn: 0.9698950	total: 5m 29s	remaining: 4m 1s
# 231:	learn: 0.9697895	total: 5m 30s	remaining: 3m 59s
# 232:	learn: 0.9698247	total: 5m 32s	remaining: 3m 58s
# 233:	learn: 0.9698352	total: 5m 34s	remaining: 3m 56s
# 234:	learn: 0.9697790	total: 5m 35s	remaining: 3m 55s
# 235:	learn: 0.9697227	total: 5m 37s	remaining: 3m 54s
# 236:	learn: 0.9698176	total: 5m 38s	remaining: 3m 52s
# 237:	learn: 0.9697438	total: 5m 39s	remaining: 3m 51s
# 238:	learn: 0.9698282	total: 5m 41s	remaining: 3m 49s
# 239:	learn: 0.9699196	total: 5m 42s	remaining: 3m 48s
# 240:	learn: 0.9699336	total: 5m 44s	remaining: 3m 47s
# 241:	learn: 0.9698528	total: 5m 45s	remaining: 3m 45s
# 242:	learn: 0.9698563	total: 5m 47s	remaining: 3m 44s
# 243:	learn: 0.9697720	total: 5m 48s	remaining: 3m 42s
# 244:	learn: 0.9697157	total: 5m 50s	remaining: 3m 41s
# 245:	learn: 0.9697087	total: 5m 51s	remaining: 3m 39s
# 246:	learn: 0.9696349	total: 5m 52s	remaining: 3m 38s
# 247:	learn: 0.9698176	total: 5m 53s	remaining: 3m 36s
# 248:	learn: 0.9699090	total: 5m 55s	remaining: 3m 35s
# 249:	learn: 0.9698774	total: 5m 57s	remaining: 3m 34s
# 250:	learn: 0.9699407	total: 5m 58s	remaining: 3m 32s
# 251:	learn: 0.9700602	total: 5m 59s	remaining: 3m 31s
# 252:	learn: 0.9702183	total: 6m 1s	remaining: 3m 30s
# 253:	learn: 0.9703168	total: 6m 3s	remaining: 3m 28s
# 254:	learn: 0.9702711	total: 6m 4s	remaining: 3m 27s
# 255:	learn: 0.9703379	total: 6m 6s	remaining: 3m 25s
# 256:	learn: 0.9703625	total: 6m 7s	remaining: 3m 24s
# 257:	learn: 0.9704503	total: 6m 8s	remaining: 3m 22s
# 258:	learn: 0.9704152	total: 6m 9s	remaining: 3m 21s
# 259:	learn: 0.9705523	total: 6m 10s	remaining: 3m 19s
# 260:	learn: 0.9706050	total: 6m 12s	remaining: 3m 18s
# 261:	learn: 0.9707175	total: 6m 13s	remaining: 3m 16s
# 262:	learn: 0.9707069	total: 6m 15s	remaining: 3m 15s
# 263:	learn: 0.9707175	total: 6m 16s	remaining: 3m 14s
# 264:	learn: 0.9706788	total: 6m 18s	remaining: 3m 12s
# 265:	learn: 0.9707561	total: 6m 19s	remaining: 3m 11s
# 266:	learn: 0.9708827	total: 6m 21s	remaining: 3m 9s
# 267:	learn: 0.9707913	total: 6m 22s	remaining: 3m 8s
# 268:	learn: 0.9707139	total: 6m 24s	remaining: 3m 7s
# 269:	learn: 0.9711287	total: 6m 25s	remaining: 3m 5s
# 270:	learn: 0.9711252	total: 6m 27s	remaining: 3m 4s
# 271:	learn: 0.9712306	total: 6m 28s	remaining: 3m 3s
# 272:	learn: 0.9711744	total: 6m 30s	remaining: 3m 1s
# 273:	learn: 0.9711814	total: 6m 31s	remaining: 3m
# 274:	learn: 0.9710971	total: 6m 33s	remaining: 2m 58s
# 275:	learn: 0.9712588	total: 6m 34s	remaining: 2m 57s
# 276:	learn: 0.9712201	total: 6m 36s	remaining: 2m 55s
# 277:	learn: 0.9712693	total: 6m 37s	remaining: 2m 54s
# 278:	learn: 0.9713220	total: 6m 38s	remaining: 2m 52s
# 279:	learn: 0.9712131	total: 6m 40s	remaining: 2m 51s
# 280:	learn: 0.9713115	total: 6m 41s	remaining: 2m 50s
# 281:	learn: 0.9713783	total: 6m 42s	remaining: 2m 48s
# 282:	learn: 0.9714872	total: 6m 44s	remaining: 2m 47s
# 283:	learn: 0.9714556	total: 6m 45s	remaining: 2m 45s
# 284:	learn: 0.9715153	total: 6m 47s	remaining: 2m 44s
# 285:	learn: 0.9714942	total: 6m 49s	remaining: 2m 43s
# 286:	learn: 0.9715224	total: 6m 50s	remaining: 2m 41s
# 287:	learn: 0.9715927	total: 6m 52s	remaining: 2m 40s
# 288:	learn: 0.9716665	total: 6m 53s	remaining: 2m 38s
# 289:	learn: 0.9716067	total: 6m 55s	remaining: 2m 37s
# 290:	learn: 0.9716313	total: 6m 56s	remaining: 2m 36s
# 291:	learn: 0.9716735	total: 6m 58s	remaining: 2m 34s
# 292:	learn: 0.9717579	total: 6m 59s	remaining: 2m 33s
# 293:	learn: 0.9717614	total: 7m	remaining: 2m 31s
# 294:	learn: 0.9718598	total: 7m 2s	remaining: 2m 30s
# 295:	learn: 0.9719301	total: 7m 3s	remaining: 2m 28s
# 296:	learn: 0.9719125	total: 7m 5s	remaining: 2m 27s
# 297:	learn: 0.9719160	total: 7m 7s	remaining: 2m 26s
# 298:	learn: 0.9719266	total: 7m 9s	remaining: 2m 25s
# 299:	learn: 0.9718914	total: 7m 11s	remaining: 2m 23s
# 300:	learn: 0.9718914	total: 7m 13s	remaining: 2m 22s
# 301:	learn: 0.9721340	total: 7m 15s	remaining: 2m 21s
# 302:	learn: 0.9720531	total: 7m 17s	remaining: 2m 19s
# 303:	learn: 0.9719688	total: 7m 18s	remaining: 2m 18s
# 304:	learn: 0.9720391	total: 7m 20s	remaining: 2m 17s
# 305:	learn: 0.9723378	total: 7m 21s	remaining: 2m 15s
# 306:	learn: 0.9723800	total: 7m 22s	remaining: 2m 14s
# 307:	learn: 0.9723835	total: 7m 24s	remaining: 2m 12s
# 308:	learn: 0.9724187	total: 7m 26s	remaining: 2m 11s
# 309:	learn: 0.9723870	total: 7m 27s	remaining: 2m 10s
# 310:	learn: 0.9723554	total: 7m 29s	remaining: 2m 8s
# 311:	learn: 0.9723202	total: 7m 31s	remaining: 2m 7s
# 312:	learn: 0.9722921	total: 7m 33s	remaining: 2m 5s
# 313:	learn: 0.9724081	total: 7m 34s	remaining: 2m 4s
# 314:	learn: 0.9724608	total: 7m 36s	remaining: 2m 3s
# 315:	learn: 0.9726506	total: 7m 37s	remaining: 2m 1s
# 316:	learn: 0.9726928	total: 7m 39s	remaining: 2m
# 317:	learn: 0.9727385	total: 7m 41s	remaining: 1m 58s
# 318:	learn: 0.9727631	total: 7m 42s	remaining: 1m 57s
# 319:	learn: 0.9727631	total: 7m 43s	remaining: 1m 55s
# 320:	learn: 0.9727702	total: 7m 45s	remaining: 1m 54s
# 321:	learn: 0.9727877	total: 7m 47s	remaining: 1m 53s
# 322:	learn: 0.9728334	total: 7m 48s	remaining: 1m 51s
# 323:	learn: 0.9727948	total: 7m 48s	remaining: 1m 49s
# 324:	learn: 0.9728686	total: 7m 50s	remaining: 1m 48s
# 325:	learn: 0.9728299	total: 7m 51s	remaining: 1m 47s
# 326:	learn: 0.9729283	total: 7m 53s	remaining: 1m 45s
# 327:	learn: 0.9729670	total: 7m 55s	remaining: 1m 44s
# 328:	learn: 0.9730549	total: 7m 56s	remaining: 1m 42s
# 329:	learn: 0.9730162	total: 7m 58s	remaining: 1m 41s
# 330:	learn: 0.9730549	total: 7m 59s	remaining: 1m 40s
# 331:	learn: 0.9730162	total: 8m 1s	remaining: 1m 38s
# 332:	learn: 0.9731111	total: 8m 2s	remaining: 1m 37s
# 333:	learn: 0.9730338	total: 8m 4s	remaining: 1m 35s
# 334:	learn: 0.9730373	total: 8m 5s	remaining: 1m 34s
# 335:	learn: 0.9730549	total: 8m 6s	remaining: 1m 32s
# 336:	learn: 0.9730900	total: 8m 8s	remaining: 1m 31s
# 337:	learn: 0.9731041	total: 8m 9s	remaining: 1m 29s
# 338:	learn: 0.9731146	total: 8m 11s	remaining: 1m 28s
# 339:	learn: 0.9731568	total: 8m 12s	remaining: 1m 26s
# 340:	learn: 0.9732271	total: 8m 14s	remaining: 1m 25s
# 341:	learn: 0.9732974	total: 8m 15s	remaining: 1m 24s
# 342:	learn: 0.9732517	total: 8m 17s	remaining: 1m 22s
# 343:	learn: 0.9731709	total: 8m 19s	remaining: 1m 21s
# 344:	learn: 0.9731146	total: 8m 21s	remaining: 1m 19s
# 345:	learn: 0.9731744	total: 8m 23s	remaining: 1m 18s
# 346:	learn: 0.9732798	total: 8m 25s	remaining: 1m 17s
# 347:	learn: 0.9733431	total: 8m 26s	remaining: 1m 15s
# 348:	learn: 0.9732939	total: 8m 28s	remaining: 1m 14s
# 349:	learn: 0.9733431	total: 8m 29s	remaining: 1m 12s
# 350:	learn: 0.9733009	total: 8m 30s	remaining: 1m 11s
# 351:	learn: 0.9732622	total: 8m 32s	remaining: 1m 9s
# 352:	learn: 0.9733396	total: 8m 33s	remaining: 1m 8s
# 353:	learn: 0.9734696	total: 8m 34s	remaining: 1m 6s
# 354:	learn: 0.9734766	total: 8m 36s	remaining: 1m 5s
# 355:	learn: 0.9734485	total: 8m 38s	remaining: 1m 4s
# 356:	learn: 0.9734977	total: 8m 40s	remaining: 1m 2s
# 357:	learn: 0.9734907	total: 8m 41s	remaining: 1m 1s
# 358:	learn: 0.9734907	total: 8m 42s	remaining: 59.7s
# 359:	learn: 0.9735575	total: 8m 43s	remaining: 58.2s
# 360:	learn: 0.9735786	total: 8m 45s	remaining: 56.7s
# 361:	learn: 0.9737227	total: 8m 46s	remaining: 55.3s
# 362:	learn: 0.9737403	total: 8m 47s	remaining: 53.8s
# 363:	learn: 0.9737016	total: 8m 49s	remaining: 52.3s
# 364:	learn: 0.9737367	total: 8m 50s	remaining: 50.9s
# 365:	learn: 0.9738070	total: 8m 52s	remaining: 49.4s
# 366:	learn: 0.9739230	total: 8m 53s	remaining: 48s
# 367:	learn: 0.9739547	total: 8m 54s	remaining: 46.5s
# 368:	learn: 0.9740320	total: 8m 55s	remaining: 45s
# 369:	learn: 0.9739863	total: 8m 57s	remaining: 43.6s
# 370:	learn: 0.9740355	total: 8m 58s	remaining: 42.1s
# 371:	learn: 0.9741831	total: 8m 59s	remaining: 40.6s
# 372:	learn: 0.9742148	total: 9m	remaining: 39.1s
# 373:	learn: 0.9741831	total: 9m 2s	remaining: 37.7s
# 374:	learn: 0.9742007	total: 9m 3s	remaining: 36.2s
# 375:	learn: 0.9743413	total: 9m 4s	remaining: 34.8s
# 376:	learn: 0.9744292	total: 9m 6s	remaining: 33.3s
# 377:	learn: 0.9744995	total: 9m 7s	remaining: 31.8s
# 378:	learn: 0.9745065	total: 9m 8s	remaining: 30.4s
# 379:	learn: 0.9744468	total: 9m 9s	remaining: 28.9s
# 380:	learn: 0.9744327	total: 9m 11s	remaining: 27.5s
# 381:	learn: 0.9744854	total: 9m 12s	remaining: 26s
# 382:	learn: 0.9745030	total: 9m 14s	remaining: 24.6s
# 383:	learn: 0.9744960	total: 9m 15s	remaining: 23.1s
# 384:	learn: 0.9746014	total: 9m 16s	remaining: 21.7s
# 385:	learn: 0.9746893	total: 9m 18s	remaining: 20.3s
# 386:	learn: 0.9748791	total: 9m 19s	remaining: 18.8s
# 387:	learn: 0.9748721	total: 9m 21s	remaining: 17.4s
# 388:	learn: 0.9749459	total: 9m 22s	remaining: 15.9s
# 389:	learn: 0.9750302	total: 9m 24s	remaining: 14.5s
# 390:	learn: 0.9750091	total: 9m 25s	remaining: 13s
# 391:	learn: 0.9750513	total: 9m 27s	remaining: 11.6s
# 392:	learn: 0.9750478	total: 9m 28s	remaining: 10.1s
# 393:	learn: 0.9750197	total: 9m 29s	remaining: 8.66s
# 394:	learn: 0.9750548	total: 9m 30s	remaining: 7.22s
# 395:	learn: 0.9750830	total: 9m 31s	remaining: 5.78s
# 396:	learn: 0.9752200	total: 9m 33s	remaining: 4.33s
# 397:	learn: 0.9753536	total: 9m 34s	remaining: 2.89s
# 398:	learn: 0.9754063	total: 9m 35s	remaining: 1.44s
# 399:	learn: 0.9753887	total: 9m 37s	remaining: 0us

# %%
#0.88997
# !kaggle competitions submit -c skill-task -f submission_cat_modified_3.csv -m "Глубина 12, 400 итераций"
# Out:
# 100%|██████████████████████████████████████| 5.89k/5.89k [00:00<00:00, 57.1kB/s]
# Successfully submitted to Skill task
